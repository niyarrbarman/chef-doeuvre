# %%
import pandas as pd
import numpy as np

# %%
file_path = "C:\\Users\\Elouan\\Documents\\Projet Biais LLM\\spotify_songs_clean.xlsx"  
xls = pd.ExcelFile(file_path)
df = xls.parse("Sheet1")

# %%
# on enlève les lignes ou les lyrics sont trop courts
df = df[df['lyrics'].str.len() > 15]
df.to_excel("C:\\Users\\Elouan\\Documents\\Projet Biais LLM\\spotify_songs_clean.xlsx", index=False)

# %%
# On va créer des sets avec les artistes, les genres de musique et les sous genres

set_artists = set(df["track_artist"])
set_genres = set(df["playlist_genre"])
set_subgenres = set(df["playlist_subgenre"])
print("Nombre d'artistes uniques : ", len(set_artists))
print("Nombre de genres uniques : ", len(set_genres))
print("Nombre de sous-genres uniques : ", len(set_subgenres))

#on créer un xlsx avec les artistes, genres et sous-genres
df_artists = pd.DataFrame(set_artists, columns=["track_artist"])
df_genres = pd.DataFrame(set_genres, columns=["playlist_genre"])
df_subgenres = pd.DataFrame(set_subgenres, columns=["playlist_subgenre"])
df_artists.to_excel("C:\\Users\\Elouan\\Documents\\Projet Biais LLM\\artists.xlsx", index=False)
df_genres.to_excel("C:\\Users\\Elouan\\Documents\\Projet Biais LLM\\genres.xlsx", index=False)
df_subgenres.to_excel("C:\\Users\\Elouan\\Documents\\Projet Biais LLM\\subgenres.xlsx", index=False)
# Out:
# Nombre d'artistes uniques :  5927
# Nombre de genres uniques :  6
# Nombre de sous-genres uniques :  24

# %%
import musicbrainzngs

musicbrainzngs.set_useragent("TrouverOrginieGeos", "0.1", "elouan.vuichard@gmail.com")

#test requête musicbrainz pr voir les infos sur un artiste
try:
    result = musicbrainzngs.browse_artists(includes=
    artist = result['artist-list'][0]
    for key, value in artist.items():
        print(f"{key}: {value}")
    print(artist['name'])
    print(artist['country'])
except musicbrainzngs.WebServiceError as e:
    print(f"Web service error occurred: {e}")

#parfait
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[56], line 7
#       5 #test requête musicbrainz pr voir les infos sur un artiste
#       6 try:
# ----> 7     result = musicbrainzngs.browse_artists(artist="Christine and the Queens", limit=1)
#       8     artist = result['artist-list'][0]
#       9     for key, value in artist.items():
#
# TypeError: browse_artists() got an unexpected keyword argument 'artist'

# %%
def clean_string(string):
    string = string.replace("&", "and")
    string = string.replace("'", "")
    string = string.replace("ó", "o")
    string = string.replace("é", "e")
    string = string.replace("è", "e")
    string = string.replace("ç", "c")
    string = string.replace("à", "a")
    string = string.replace(" ","")
    string = string.replace("-", "")
    string = string.replace("_", "")
    string = string.strip()
    return string.lower()

def get_country_and_gender(artist_name):
    limite = 5
    try:
        result = musicbrainzngs.search_artists(artist=artist_name, limit=limite)
        if not result['artist-list']:
            print("Aucun artiste trouvé pour : ", artist_name)
            return "Unknown", "Unknown"
        
        artist = None
        for i in range(len(result['artist-list'])):
            if clean_string(artist_name) == clean_string(result['artist-list'][i]['name']):
                artist = result['artist-list'][i]
                break

        if not artist:
            noms_trouves = ", ".join([a['name'] for a in result['artist-list']])
            print("Aucun artiste correspondant trouvé pour : ", artist_name, 
                  ". Noms trouvés : ", noms_trouves)
            return "Unknown", "Unknown"
        
        pays = get_pays(artist)
        genre = get_genre(artist)
        return pays,genre
    
    except musicbrainzngs.WebServiceError as e:
        print(f"Web service error occurred: {e}")
        return None

def get_genre(artist):
    if 'type' in artist:
        if artist['type'] == 'Person' and 'gender' in artist:
            genre = artist['gender']
        else:
            genre = artist['type']
    else:
        genre = "Unknown"
    return genre

def get_pays(artist):
    if 'country' in artist:
        pays = artist['country']
    else:
        pays = "Unknown"
    return pays

# %%
LIMITE = -1
# on créer deux nouvelles colonnes dans le df : pays et genre
file = "C:\\Users\\Elouan\\Documents\\Projet Biais LLM\\artists.xlsx"
df_artists = pd.read_excel(file)
df_artists['pays'] = None
df_artists['genre'] = None

for index, row in df_artists.iterrows():
    artist_name = row['track_artist']
    pays, genre = get_country_and_gender(str(artist_name))
    if pays is not None and genre is not None:
        df_artists.at[index, 'pays'] = pays
        df_artists.at[index, 'genre'] = genre
    else:
        print(f"Could not retrieve data for artist: {artist_name}")
    if index >= LIMITE and LIMITE != -1:
        print("Limite de " + str(LIMITE) + " atteinte")
        break
# Out:
# Aucun artiste trouvé pour :  Yady
# Aucun artiste correspondant trouvé pour :  Frans . Noms trouvés :  Frans Bauer, Frans Brüggen, Frans Halsema, Frans Duijts, Frans van Steijn
# Aucun artiste correspondant trouvé pour :  Lil West . Noms trouvés :  Lil Wayne, Lil B, Lil Uzi Vert, Go West, Lil Durk
# Aucun artiste correspondant trouvé pour :  Art Aguilera . Noms trouvés :  Christina Aguilera, Art Tatum, Art Pepper, Art Farmer, Art Blakey
# Aucun artiste correspondant trouvé pour :  Daniel Skye . Noms trouvés :  Daniel Barenboim, Daniel Pemberton, Daniel C. Holter, Emily Skye, Daniel Alexander
# Aucun artiste correspondant trouvé pour :  August Roads . Noms trouvés :  August Zirner, August Burns Red, Roads, Roads, Christian August Vulpius
# Aucun artiste correspondant trouvé pour :  Keys of Philadelphia . Noms trouvés :  Hot Club of Philadelphia, Chamber Symphony of Philadelphia, Chamber Orchestra of Philadelphia, Mendelssohn Club of Philadelphia, Soul Satisfiers Of Philadelphia
# Aucun artiste correspondant trouvé pour :  Adam K . Noms trouvés :  J. K. Rowling, Philip K. Dick, Adam Drake, Adam Routh, Adam Saunders
# Aucun artiste correspondant trouvé pour :  (Sandy) Alex G . Noms trouvés :  Alex G, Alex G, Alex G., Alex.G., Alex G
# Aucun artiste correspondant trouvé pour :  Matt Moore . Noms trouvés :  Gary Moore, R. Stevie Moore, Matt Monro, Matt Fitton, Gerald Moore
# Aucun artiste correspondant trouvé pour :  The Sacados . Noms trouvés :  The Beatles, The Rolling Stones, The E Street Band, The Beach Boys, The Smashing Pumpkins
# Aucun artiste trouvé pour :  Waxwane
# Aucun artiste trouvé pour :  SIXN
# Aucun artiste trouvé pour :  YOUNGJAE
# Aucun artiste correspondant trouvé pour :  DJ Ross . Noms trouvés :  Diana Ross, Atticus Ross, DJ BoBo, Rick Ross, DJ Shadow
# Aucun artiste correspondant trouvé pour :  King Harvest . Noms trouvés :  Stephen King, Nat King Cole, B.B. King, King Crimson, Carole King
# Aucun artiste trouvé pour :  Stackztootrill
# Aucun artiste correspondant trouvé pour :  Dan Hill . Noms trouvés :  Dan Brown, Jonny Hill, Steely Dan, Cypress Hill, Dan Gibson
# Aucun artiste correspondant trouvé pour :  Lil Whigga . Noms trouvés :  Lil Wayne, Lil B, Lil Uzi Vert, Lil Durk, Lil Baby
# Aucun artiste correspondant trouvé pour :  The Revivalists . Noms trouvés :  The Beatles, The Rolling Stones, The E Street Band, The Beach Boys, The Smashing Pumpkins
# Aucun artiste correspondant trouvé pour :  Somethin' For The People . Noms trouvés :  Somethin’ for the People, Disco for the People, Anthrax for The People, Gambia for the People, Nahko & Medicine for the People
# Aucun artiste correspondant trouvé pour :  Lin-Manuel Miranda . Noms trouvés :  Lin‐Manuel Miranda, Manuel de Falla, Miranda Lambert, Miranda!, Víctor Manuel
# Aucun artiste correspondant trouvé pour :  Lipps Inc. . Noms trouvés :  Lipps, Inc., Milk Inc., MONO INC., Hot Lipps Inc, でんぱ組.inc
# Aucun artiste correspondant trouvé pour :  Blvck O . Noms trouvés :  Type O Negative, Sunn O))), O-Zone, BLVCK, BLVCK
# Aucun artiste correspondant trouvé pour :  Bright Ones . Noms trouvés :  Bright Eyes, and all was bright, Bright Light Bright Light, BRIGHT, The Only Ones
# Aucun artiste correspondant trouvé pour :  Lia Marquis . Noms trouvés :  Lia, Marquis Laughlin, Marquis Hill, Lofi Lia, Marquis
# Aucun artiste correspondant trouvé pour :  West Gold . Noms trouvés :  Murray Gold, Go West, Andrew Gold, Dottie West, Gold
# Aucun artiste correspondant trouvé pour :  Sueco the Child . Noms trouvés :  Sueco, The Child, The Child, Louis the Child, The Child Molesters
# Aucun artiste correspondant trouvé pour :  Taylor Gang . Noms trouvés :  Taylor Swift, Kool & the Gang, James Taylor, Charles Taylor, Gang Starr
# Aucun artiste correspondant trouvé pour :  Lady Antebellum . Noms trouvés :  Lady Gaga, Lady A, Antebellum, Antebellum, Lady Pank
# Aucun artiste correspondant trouvé pour :  Paul Stanley . Noms trouvés :  Paul McCartney, Paul Dinletir, The Stanley Brothers, Paul Mauriat, Paul Anka
# Aucun artiste correspondant trouvé pour :  Ray Parker, Jr. . Noms trouvés :  Ray Parker Jr., Orlando Parker Jr, Samuel Parker Jr., Maceo Parker, Warren T. Parker, Jr.
# Aucun artiste correspondant trouvé pour :  Frank Walker . Noms trouvés :  Frank Sinatra, Frank Zappa, Frank Arnold, Frank Herbert, Frank Schätzing
# Aucun artiste correspondant trouvé pour :  MAX . Noms trouvés :  Max Reger, Max Richter, Max Steiner, Max Roach, Max Bruch
# Aucun artiste correspondant trouvé pour :  Sebastian Yatra . Noms trouvés :  Johann Sebastian Bach, Sebastián Yatra, Sebastian Fitzek, Sebastian, Belle and Sebastian
# Aucun artiste correspondant trouvé pour :  Miles Casper . Noms trouvés :  Miles Davis, Casper, Robert Miles, Miles Davis Quintet, Casper Miles
# Aucun artiste correspondant trouvé pour :  Kid Frost . Noms trouvés :  Zippy Kid, Kid Cudi, Celtic Frost, The Jaffa Kid, Frost*
# Aucun artiste correspondant trouvé pour :  MAJOR. . Noms trouvés :  Major Lazer, Major Lance, Henriette Major, Major Accident, Major Parkinson
# Aucun artiste correspondant trouvé pour :  Otis Junior . Noms trouvés :  Otis Redding, Otis Rush, Junior Wells, Otis Spann, SUPER JUNIOR
# Aucun artiste correspondant trouvé pour :  Kris Wu . Noms trouvés :  Kris Kristofferson, Wu‐Tang Clan, Kris Bowers, Nancy Wu, Kris Menace
# Aucun artiste correspondant trouvé pour :  Drizabone . Noms trouvés :  The Drizabone Soul Family
# Aucun artiste correspondant trouvé pour :  Tony Junior . Noms trouvés :  Tony Bennett, Tony Robinson, Junior Wells, Tony Marshall, SUPER JUNIOR
# Aucun artiste correspondant trouvé pour :  Ice-T . Noms trouvés :  Ice‐T, T. Rex, Ice Cube, T‐Bone Walker, T‐SQUARE
# Aucun artiste correspondant trouvé pour :  Big Matt . Noms trouvés :  Big Country, Mr. Big, Big Bill Broonzy, Matt Monro, Matt Fitton
# Aucun artiste correspondant trouvé pour :  Chester Nebro . Noms trouvés :  Johnny Chester, Chester W., Ilan Chester, Chester Watson, Chester
# Aucun artiste correspondant trouvé pour :  Jay Made . Noms trouvés :  JAY‐Z, William Jay Bergman, Jay-Jay Johanson, Screamin’ Jay Hawkins, Jay Kristoff
# Aucun artiste correspondant trouvé pour :  Galante "El Emperador" . Noms trouvés :  Galante “El Emperador”, Neon, el Emperador, JC El Emperador, Europa Galante, Emperador
# Aucun artiste correspondant trouvé pour :  Mc Tha . Noms trouvés :  Tha Soloist, Tha God Fahim, Noize MC, Tha Playah, MC Hammer
# Aucun artiste correspondant trouvé pour :  Brooks . Noms trouvés :  Garth Brooks, Terry Brooks, Elkie Brooks, Brooks & Dunn, Mel Brooks
# Aucun artiste correspondant trouvé pour :  Quinn Lewis . Noms trouvés :  Jerry Lee Lewis, Freddy Quinn, C. S. Lewis, Ramsey Lewis, Leona Lewis
# Aucun artiste correspondant trouvé pour :  Jey Blessing . Noms trouvés :  Sharam Jey, Jey-Jey, Blessing, The Blessing, Jey
# Aucun artiste correspondant trouvé pour :  Casey Conroy . Noms trouvés :  Casey Kasem, Karl Casey, Warren Casey, Casey, Casey
# Aucun artiste correspondant trouvé pour :  Mark Mendy . Noms trouvés :  Mark Knopfler, Mark Isham, Mark Mancina, Mark Mothersbaugh, Mark Twain
# Aucun artiste correspondant trouvé pour :  The Internet . Noms trouvés :  The Beatles, The Rolling Stones, The E Street Band, The Beach Boys, The Smashing Pumpkins
# Aucun artiste correspondant trouvé pour :  Avine Vinny . Noms trouvés :  Ávine Vinny, Vinny, Vinny Golia, Vinny, Vinny Millevolte
# Aucun artiste correspondant trouvé pour :  The Wrecks . Noms trouvés :  The Beatles, The Rolling Stones, The E Street Band, The Beach Boys, The Smashing Pumpkins
# Aucun artiste correspondant trouvé pour :  Pete Rock / InI . Noms trouvés :  Pete Rock, Pete Seeger, Pete Townshend, Twinkle Twinkle Little Rock Star, Ini Kamoze
# Aucun artiste correspondant trouvé pour :  Ne-Yo . Noms trouvés :  Ne‐Yo, Yo La Tengo, Yö, Yo‐Yo Ma, Yo Gotti
# Aucun artiste correspondant trouvé pour :  Red . Noms trouvés :  Red Hot Chili Peppers, Simply Red, Red Velvet, Tampa Red, Red Garland
# Aucun artiste correspondant trouvé pour :  Nina Tribus . Noms trouvés :  Nina Simone, Nina Petri, Nina Hagen, Nina Kunzendorf, Tribus
# Aucun artiste correspondant trouvé pour :  Michel'le . Noms trouvés :  Michel’le
# Aucun artiste correspondant trouvé pour :  Mike Williams . Noms trouvés :  John Williams, Tad Williams, Andy Williams, Hank Williams, Robbie Williams
# Aucun artiste correspondant trouvé pour :  Little Giants . Noms trouvés :  Little Richard, They Might Be Giants, Little Feat, Twinkle Twinkle Little Rock Star, Little Walter
# Aucun artiste correspondant trouvé pour :  Los Delinquentes . Noms trouvés :  Los Delinqüentes, Los Lobos, Los Panchos, Delinquentes, Los Alegres de Terán
# Aucun artiste correspondant trouvé pour :  Afu-Ra . Noms trouvés :  Afu‐Ra, Sun Ra, The Sun Ra Arkestra, Afu, Ra Ra Riot
# Aucun artiste correspondant trouvé pour :  Rex Smith . Noms trouvés :  T. Rex, Rex Gildo, Elliott Smith, Bessie Smith, Jimmy Smith
# Aucun artiste correspondant trouvé pour :  Lil' Flip . Noms trouvés :  Lil’ Flip, Lil Wayne, Lil B, Flip Phillips, Lil Uzi Vert
# Aucun artiste correspondant trouvé pour :  Carl Anderson . Noms trouvés :  Carl Perkins, Carl Orff, Carl Philipp Emanuel Bach, Lynn Anderson, Carl Nielsen
# Aucun artiste correspondant trouvé pour :  Mc Don Juan . Noms trouvés :  Don Juan, Don Juan, Don Juan, Don Juan, Don Juan
# Aucun artiste trouvé pour :  PayAttention
# Aucun artiste correspondant trouvé pour :  Danny Romero . Noms trouvés :  Danny Elfman, Danny Pelfrey, Paul Romero, Danny, Nicky Romero
# Aucun artiste correspondant trouvé pour :  David Soul . Noms trouvés :  David Bowie, David Nathan, David Arnold, David Guetta, Soul Asylum
# Aucun artiste correspondant trouvé pour :  Dirty South & Alesso . Noms trouvés :  Alesso, Dirty South, Duke Ellington and His Orchestra, Bob Marley & The Wailers, Astral & Shit
# Aucun artiste correspondant trouvé pour :  Trip Lee . Noms trouvés :  John Lee Hooker, Jerry Lee Lewis, Peggy Lee, Brenda Lee, Lee Child
# Aucun artiste correspondant trouvé pour :  Christian French . Noms trouvés :  Christian Brückner, Christian Tramitz, Tana French, Christian Berkel, Nicci French
# Aucun artiste correspondant trouvé pour :  Of Allies . Noms trouvés :  Bull of Heaven, 7 Minutes of Nausea, Wings of an Angel, The City of Prague Philharmonic Orchestra, Ace of Base
# Aucun artiste correspondant trouvé pour :  Marci Coleman . Noms trouvés :  Coleman Hawkins, Ornette Coleman, Cy Coleman, Marci, Bill Coleman
# Aucun artiste correspondant trouvé pour :  Camur . Noms trouvés :  Çamur
# Aucun artiste correspondant trouvé pour :  Wish & Fonda Rae . Noms trouvés :  Fonda Rae, Duke Ellington and His Orchestra, Bob Marley & The Wailers, Astral & Shit, Bibi & Tina
# Aucun artiste correspondant trouvé pour :  Gotay "El Autentiko" . Noms trouvés :  Gotay el Auténtiko, Auténtiko, El Tri, El Gran Combo de Puerto Rico, El‐P
# Aucun artiste correspondant trouvé pour :  Cookin' On 3 Burners . Noms trouvés :  Cookin’ on 3 Burners, Cookin’ Soul, cosmic lace on broken bones, 3 Doors Down, Alabama 3
# Aucun artiste correspondant trouvé pour :  Big Mike . Noms trouvés :  Mike Oldfield, Big Country, Mr. Big, Big Bill Broonzy, Big Joe Turner
# Aucun artiste correspondant trouvé pour :  Til Tuesday . Noms trouvés :  ’Til Tuesday, Fixed Til Tuesday, The Real Tuesday Weld, Tuesday, TIL
# Aucun artiste correspondant trouvé pour :  Matt Terry . Noms trouvés :  Terry Pratchett, Terry Devine-King, Terry Brooks, Clark Terry, Todd Terry
# Aucun artiste correspondant trouvé pour :  Hot Shade . Noms trouvés :  Shade, Red Hot Chili Peppers, Booka Shade, Hot Chocolate, Hot Chip
# Aucun artiste correspondant trouvé pour :  Heather Schnoor . Noms trouvés :  Heather Nova, Heather Small, Heather Dale, Heather Jones, Camille Schnoor
# Aucun artiste trouvé pour :  IliassOpDeBeat
# Aucun artiste correspondant trouvé pour :  Lucas Muto . Noms trouvés :  MUTO, M.U.T.O, MUTO, muto, Muto’S
# Aucun artiste correspondant trouvé pour :  Franco "El Gorilla" . Noms trouvés :  Franco “El Gorila”, Franco Battiato, Franco Micalizzi, Gorilla Zoe, Gorilla Biscuits
# Aucun artiste correspondant trouvé pour :  Indi Star . Noms trouvés :  Twinkle Twinkle Little Rock Star, Big Star, Indi, Five Star, Midnight Star
# Aucun artiste correspondant trouvé pour :  Brian Mackey . Noms trouvés :  Brian Eno, Brian Tyler, Brian Jacques, Brian Bennett, Brian McKnight
# Aucun artiste correspondant trouvé pour :  The Twinz . Noms trouvés :  The Beatles, The Rolling Stones, The E Street Band, The Beach Boys, The Smashing Pumpkins
# Aucun artiste correspondant trouvé pour :  Mike Stanley . Noms trouvés :  The Stanley Brothers, Mike Oldfield, Stanley Turrentine, Ralph Stanley, Stanley Clarke
# Aucun artiste correspondant trouvé pour :  Mike Jones . Noms trouvés :  George Jones, Tom Jones, Norah Jones, Quincy Jones, Mike Oldfield
# Aucun artiste correspondant trouvé pour :  Gavin James . Noms trouvés :  James Last, James Brown, James Horner, Etta James, James Newton Howard
# Aucun artiste correspondant trouvé pour :  Yung Skii . Noms trouvés :  Skii, Yung Lean, Mon-skii, Skii xse, Yung Pinch
# Aucun artiste correspondant trouvé pour :  Connor Bvrns . Noms trouvés :  Chris Connor, Sarah Connor, Bill Connor, Jon Connor, Joanna Connor
# Aucun artiste correspondant trouvé pour :  JOY. . Noms trouvés :  Joy Division, Joy Fleming, Livin’ Joy, Vance Joy, Joy
# Aucun artiste correspondant trouvé pour :  Thomas Jack . Noms trouvés :  Thomas Bergersen, Thomas Newman, Jack Johnson, Michel Thomas, Jack Higgins
# Aucun artiste correspondant trouvé pour :  Compton's Most Wanted . Noms trouvés :  Compton’s Most Wanted, Most Wanted, Most Wanted, Most Wanted, MOST WANTED
# Aucun artiste correspondant trouvé pour :  Ab-Soul . Noms trouvés :  Ab‐Soul, Soul Asylum, Soul II Soul, De La Soul, Collective Soul
# Aucun artiste correspondant trouvé pour :  King Deco . Noms trouvés :  Stephen King, Nat King Cole, B.B. King, King Crimson, Carole King
# Aucun artiste correspondant trouvé pour :  Axwell /\ Ingrosso . Noms trouvés :  Axwell Λ Ingrosso, Axwell, Sebastian Ingrosso, Benjamin Ingrosso, Ingrosso
# Aucun artiste correspondant trouvé pour :  Lauren Presley . Noms trouvés :  Elvis Presley, Devilish Presley, Lauren Daigle, Meyhem Lauren, Christina Lauren
# Aucun artiste correspondant trouvé pour :  Celo & Abdi . Noms trouvés :  Ćelo & Abdï, Duke Ellington and His Orchestra, Bob Marley & The Wailers, Astral & Shit, Bibi & Tina
# Aucun artiste correspondant trouvé pour :  The Cratez . Noms trouvés :  The Beatles, The Rolling Stones, The E Street Band, The Beach Boys, The Smashing Pumpkins
# Aucun artiste correspondant trouvé pour :  The Wanted . Noms trouvés :  The Beatles, The Rolling Stones, The E Street Band, The Beach Boys, The Smashing Pumpkins
# Aucun artiste correspondant trouvé pour :  DAY . Noms trouvés :  Doris Day, Green Day, Terry Day, Third Day, The Church of Jesus Christ of Latter-day Saints
# Aucun artiste correspondant trouvé pour :  Hey Guy . Noms trouvés :  Buddy Guy, Hey, Guy Béart, Hey! Say! JUMP, Guy Mitchell
# Aucun artiste correspondant trouvé pour :  Jane's Addiction . Noms trouvés :  Jane’s Addiction, Jane Austen, Jane Birkin, Jane Siberry, Jane Morgan
# Aucun artiste correspondant trouvé pour :  Jim James . Noms trouvés :  Jim Reeves, James Last, James Brown, James Horner, Etta James
# Aucun artiste correspondant trouvé pour :  Mann . Noms trouvés :  Manfred Mann, Jonathan Mann, Herbie Mann, Thomas Mann, Aimee Mann
# Aucun artiste correspondant trouvé pour :  Hues Corporation . Noms trouvés :  The Hues Corporation, Thievery Corporation, 3A Corporation, UNDEAD CORPORATION, Hues
# Aucun artiste correspondant trouvé pour :  Sasha Sloan . Noms trouvés :  Sloan, Sasha, Sasha, Sasha Alex Sloan, P.F. Sloan
# Aucun artiste correspondant trouvé pour :  Mos Def . Noms trouvés :  Def Leppard, Mos Generator, Def Con Dos, The Yah Mos Def, M.O.S.
# Aucun artiste correspondant trouvé pour :  Big Wild . Noms trouvés :  Big Country, Running Wild, Mr. Big, Big Bill Broonzy, Big Joe Turner
# Aucun artiste correspondant trouvé pour :  Blake Rose . Noms trouvés :  Karen Rose, Blake Neely, Rose Royce, James Blake, Blake Shelton
# Aucun artiste correspondant trouvé pour :  Christopher Williams . Noms trouvés :  John Williams, Tad Williams, Andy Williams, Hank Williams, Robbie Williams
# Aucun artiste correspondant trouvé pour :  Giveon . Noms trouvés :  GIVĒON, Giveon Cornfield
# Aucun artiste correspondant trouvé pour :  Chris Viz . Noms trouvés :  Chris Rea, Chris Hajian, Chris Brown, Chris de Burgh, Chris Norman
# Aucun artiste correspondant trouvé pour :  Alexander O'Neal . Noms trouvés :  Alexander O’Neal, Peter Alexander, Daniel Alexander, Alexander Scourby, Alexander Brandon
# Aucun artiste correspondant trouvé pour :  JAY-Z . Noms trouvés :  JAY‐Z, Michael Z. Land, Z‐Ro, William Jay Bergman, Jay-Jay Johanson
# Aucun artiste correspondant trouvé pour :  John Newman . Noms trouvés :  John Williams, Elton John, John Lennon, Thomas Newman, John Lee Hooker
# Aucun artiste correspondant trouvé pour :  Hot Boys . Noms trouvés :  The Beach Boys, Pet Shop Boys, Beastie Boys, Red Hot Chili Peppers, Backstreet Boys
# Aucun artiste correspondant trouvé pour :  Trove . Noms trouvés :  Jordan Trove, Wanderer’s Trove
# Aucun artiste correspondant trouvé pour :  Magic Man . Noms trouvés :  Yellow Magic Orchestra, Beenie Man, Brotherhood of Man, Man, Captain Beefheart & His Magic Band
# Aucun artiste correspondant trouvé pour :  Matt Hunter . Noms trouvés :  Erin Hunter, Ian Hunter, Matt Monro, Matt Fitton, Matt Bianco
# Aucun artiste correspondant trouvé pour :  Dimelo Flow . Noms trouvés :  FLOW, Dímelo Flow, Free Flow Flava, Company Flow, Dimelo Mic
# Aucun artiste correspondant trouvé pour :  Entre Linhas . Noms trouvés :  Entre Ríos, Entre Aspas, Entre, Entre Vifs, Entre-Knobs
# Aucun artiste trouvé pour :  Jeriqo
# Aucun artiste correspondant trouvé pour :  J-Kwon . Noms trouvés :  J. K. Rowling, D. J. MacHale, J‐Kwon, J Dilla, Robert J. Foster
# Aucun artiste correspondant trouvé pour :  Johnny Kemp . Noms trouvés :  Johnny Cash, Johnny Hallyday, Johnny Mathis, Johnny Winter, Johnny Horton
# Aucun artiste correspondant trouvé pour :  Austin P. McKenzie . Noms trouvés :  P!nk, Scott P. Schreer, Austin Wintory, H. P. Lovecraft, S. P. Balasubrahmanyam
# Aucun artiste trouvé pour :  PXNDX
# Aucun artiste correspondant trouvé pour :  Noel . Noms trouvés :  Noël Coward, Noël Akchoté, Noel Gallagher’s High Flying Birds, Magali Noël, Noel Dennis
# Aucun artiste correspondant trouvé pour :  The Honeydrippers . Noms trouvés :  The Beatles, The Rolling Stones, The E Street Band, The Beach Boys, The Smashing Pumpkins
# Aucun artiste trouvé pour :  JYWRRN
# Aucun artiste correspondant trouvé pour :  K-OS . Noms trouvés :  J. K. Rowling, k‐os, Philip K. Dick, Os Mutantes, K. S. Chithra
# Aucun artiste correspondant trouvé pour :  Alice Francis . Noms trouvés :  Alice Cooper, Francis Poulenc, Connie Francis, Alice Cooper, Alice in Chains
# Aucun artiste correspondant trouvé pour :  R. City . Noms trouvés :  George R. R. Martin, R. Kelly, City, The City of Prague Philharmonic Orchestra, R. Stevie Moore
# Aucun artiste correspondant trouvé pour :  Jakob Ogawa . Noms trouvés :  Johann Jakob Froberger, Jakob Wassermann, Jakob Lindberg, Jakob, Jakob Bro
# Aucun artiste correspondant trouvé pour :  The Drums . Noms trouvés :  The Beatles, The Rolling Stones, The E Street Band, The Beach Boys, The Smashing Pumpkins
# Aucun artiste correspondant trouvé pour :  C-Kan . Noms trouvés :  Jean C. Roché, KAN, Patrice C. Irving, C. S. Lewis, C‐Kan
# Aucun artiste correspondant trouvé pour :  DEAN . Noms trouvés :  Dean Martin, Dean Koontz, Jan & Dean, Dean Barrett, Hazell Dean
# Aucun artiste correspondant trouvé pour :  James . Noms trouvés :  James Last, James Brown, James Horner, Etta James, James Newton Howard
# Aucun artiste correspondant trouvé pour :  Josh Stanley . Noms trouvés :  The Stanley Brothers, Stanley Turrentine, Ralph Stanley, Stanley Clarke, Josh Ritter
# Aucun artiste correspondant trouvé pour :  Why Don't We . Noms trouvés :  Why Don’t We, Don't We All, WHY?, EQ Why, We Are Scientists
# Aucun artiste correspondant trouvé pour :  Rafaga . Noms trouvés :  Ráfaga, Rafaga Norteña, Rafaga de Viento
# Aucun artiste correspondant trouvé pour :  T-Pain . Noms trouvés :  T‐Pain, T. Rex, Pain, T‐Bone Walker, T‐SQUARE
# Aucun artiste correspondant trouvé pour :  Michael Johnson . Noms trouvés :  Michael Jackson, Michael Schwarzmaier, Michael Giacchino, Michael Kramer, Michael Ende
# Aucun artiste correspondant trouvé pour :  Vicente Garcia . Noms trouvés :  Vicente Fernández, Jerry Garcia, Vicente García, Charly García, Jerry Garcia Band
# Aucun artiste correspondant trouvé pour :  Young Summer . Noms trouvés :  Neil Young, Donna Summer, Lester Young, Christopher Young, Paul Young
# Aucun artiste correspondant trouvé pour :  YBN Cordae . Noms trouvés :  Cordae, Cordae/la Talvera, YBN Nahmir, June Cordae, YBN Rondo
# Aucun artiste correspondant trouvé pour :  Alejandra Guzman . Noms trouvés :  Alejandra Guzmán, Enrique Guzmán, Carlos Guzmán, Golya Guzman, Alejandra
# Aucun artiste correspondant trouvé pour :  Wreckx-N-Effect . Noms trouvés :  Wreckx‐n‐Effect, Guns N’ Roses, N‐Trance, Bone Thugs‐n‐Harmony, Salt‐N‐Pepa
# Aucun artiste correspondant trouvé pour :  Naomi Scott . Noms trouvés :  Scott Lawlor, Scott Brick, Orson Scott Card, Scott P. Schreer, Scott Joplin
# Aucun artiste correspondant trouvé pour :  Marrakesh . Noms trouvés :  Marrakesh ʘ, Marrakesh Massive, Marrakesh Orchestra, Marrakesh Express, Gnawa Music of Marrakesh
# Aucun artiste correspondant trouvé pour :  H-Town . Noms trouvés :  H‐Town, H. P. Lovecraft, H. G. Francis, Arthur H, Andreas H. Schmachtl
# Aucun artiste correspondant trouvé pour :  Chris Viviano . Noms trouvés :  Chris Rea, Chris Hajian, Chris Brown, Chris de Burgh, Chris Norman
# Aucun artiste correspondant trouvé pour :  End of the World . Noms trouvés :  Light of the World, King Of The World, World Of the WORLD., The End of the World, Drums of the World
# Aucun artiste correspondant trouvé pour :  Heaven's Basement . Noms trouvés :  Bull of Heaven, Basement Jaxx, Heaven’s Basement, Heaven 17, Heaven Shall Burn
# Aucun artiste correspondant trouvé pour :  j mena . Noms trouvés :  J. K. Rowling, D. J. MacHale, J Dilla, Robert J. Foster, Mary J. Blige
# Aucun artiste correspondant trouvé pour :  Steve Void . Noms trouvés :  Steve Hackett, Steve Roach, Steve Winwood, Steve Earle, Steve Jablonsky
# Aucun artiste correspondant trouvé pour :  Heavy D & The Boyz . Noms trouvés :  Heavy D. & the Boyz, Heavy D. & The Boyz With Friends, The Beatles, The Rolling Stones, The E Street Band
# Aucun artiste correspondant trouvé pour :  The Buggles . Noms trouvés :  The Beatles, Buggles, The Rolling Stones, The E Street Band, The Beach Boys
# Aucun artiste correspondant trouvé pour :  Sr Pablo . Noms trouvés :  Augustus Pablo, Pablo Milanés, Sr. Pablo, Sr. Chinarro, Pablo Cebrián
# Aucun artiste correspondant trouvé pour :  Kwame And A New Beginning . Noms trouvés :  New Order, Duke Ellington and His Orchestra, Bob Marley & The Wailers, A New Beginning, a‐ha
# Aucun artiste correspondant trouvé pour :  Olivia Creutzer . Noms trouvés :  Olivia Newton‐John, Olivia Rodrigo, OLIVIA, Olivia, The Olivia Tremor Control
# Aucun artiste correspondant trouvé pour :  Dylan Wild . Noms trouvés :  Bob Dylan, Running Wild, Dylan Baker, Wild Cherry, Dylan
# Aucun artiste trouvé pour :  Rubayne
# Aucun artiste correspondant trouvé pour :  James Fortune . Noms trouvés :  James Last, James Brown, James Horner, Etta James, James Newton Howard
# Aucun artiste correspondant trouvé pour :  Rich Brian . Noms trouvés :  Brian Eno, Charlie Rich, Brian Tyler, Buddy Rich, Robert Rich
# Aucun artiste correspondant trouvé pour :  The Tony Rich Project . Noms trouvés :  Tony Rich, The Beatles, The Rolling Stones, The E Street Band, Tony Bennett
# Aucun artiste correspondant trouvé pour :  Amplify Worship . Noms trouvés :  Hillsong Worship, WORSHIP, Amplify, Amplify, Elevation Worship
# Aucun artiste correspondant trouvé pour :  Nova y Jory . Noms trouvés :  Nova & Jory, Heather Nova, Roupa Nova, Curren$y, Jory John
# Aucun artiste correspondant trouvé pour :  Nick Strand . Noms trouvés :  Nick Phoenix, Nick Podehl, Nick Cave & the Bad Seeds, Nick Lowe, Nick Cave
# Aucun artiste correspondant trouvé pour :  Tyler Shaw . Noms trouvés :  Bonnie Tyler, Brian Tyler, Artie Shaw, Tyler Bates, Sandie Shaw
# Aucun artiste correspondant trouvé pour :  bLAck pARty . Noms trouvés :  Black Sabbath, Roy Black, Bloc Party, The Black Crowes, Bläck Fööss
# Aucun artiste correspondant trouvé pour :  Black Coast . Noms trouvés :  Black Sabbath, Roy Black, The Black Crowes, Bläck Fööss, Black Eyed Peas
# Aucun artiste correspondant trouvé pour :  Kevin . Noms trouvés :  Kevin MacLeod, Kevin Rix, Kevin Kiner, Kevin Hearne, Kevin Drumm
# Aucun artiste correspondant trouvé pour :  The Dø . Noms trouvés :  The Beatles, The Rolling Stones, The E Street Band, The Beach Boys, The Smashing Pumpkins
# Aucun artiste correspondant trouvé pour :  V-One . Noms trouvés :  Riot V, One Direction, Marco V, KRS‐One, And One
# Aucun artiste correspondant trouvé pour :  Sir Mix-A-Lot . Noms trouvés :  Sir Mix‐A‐Lot, Kid Mix-A-Lot, HOYO-MiX, Sir Arthur Conan Doyle, Little Mix
# Aucun artiste correspondant trouvé pour :  Joe Jonas . Noms trouvés :  Joe Cocker, Joe Dassin, Joe Jackson, Joe Satriani, Joe Bonamassa
# Aucun artiste correspondant trouvé pour :  The Spacies . Noms trouvés :  The Beatles, The Rolling Stones, The E Street Band, The Beach Boys, The Smashing Pumpkins
# Aucun artiste correspondant trouvé pour :  Larry 44 . Noms trouvés :  Larry Coryell, Larry Norman, +44, Larry Carlton, Larry Williams
# Aucun artiste correspondant trouvé pour :  Christine and the Queens . Noms trouvés :  Shirley Gunter & The Queens, Piston Mahlathini & The Queens, The Beatles, Miss Murgatroid and The Queens of Heart, The Rolling Stones
# Aucun artiste correspondant trouvé pour :  Davai . Noms trouvés :  Davaï, Davaï!, Davai Ciass
# Aucun artiste correspondant trouvé pour :  Young Bombs . Noms trouvés :  Neil Young, Lester Young, Christopher Young, Paul Young, Faron Young
# Aucun artiste correspondant trouvé pour :  Ben Esser . Noms trouvés :  Ben Webster, Ben E. King, Ben Folds, Ben Harper, Marco Eßer
# Aucun artiste correspondant trouvé pour :  CLAY . Noms trouvés :  Jars of Clay, Otis Clay, Philippe Clay, Clay Walker, Clay Aiken
# Aucun artiste correspondant trouvé pour :  Andrew McMahon in the Wilderness . Noms trouvés :  Andrew McMahon, The Beatles, The Rolling Stones, The E Street Band, The Beach Boys
# Aucun artiste correspondant trouvé pour :  Yung Felix . Noms trouvés :  Felix Mendelssohn, Felix von Manteuffel, Félix Leclerc, Felix Janosa, Hubert-Félix Thiéfaine
# Aucun artiste correspondant trouvé pour :  Phil Campbell . Noms trouvés :  Glen Campbell, Phil Collins, Joseph Campbell, Phil Gigante, Phil Woods
# Aucun artiste correspondant trouvé pour :  The Go-Go's . Noms trouvés :  Go‐Go’s, The Go-Go’s, The Go-Go’s, The Au Go-Go's, The A Go-Gos
# Aucun artiste correspondant trouvé pour :  D-Block Europe . Noms trouvés :  Europe, D‐Block Europe, D. J. MacHale, D, D‐Block
# Aucun artiste correspondant trouvé pour :  Midnight Kids . Noms trouvés :  Die drei ??? Kids, Midnight Oil, Cedarmont Kids, The Countdown Kids, Dexys Midnight Runners
# Aucun artiste correspondant trouvé pour :  Rim'K . Noms trouvés :  Rim’K
# Aucun artiste correspondant trouvé pour :  Fabio Carry . Noms trouvés :  Fabio Frizzi, Fabio Biondi, Fabio Concato, Fábio Jr., Carry
# Aucun artiste correspondant trouvé pour :  The Veils . Noms trouvés :  The Beatles, The Rolling Stones, The E Street Band, The Beach Boys, The Smashing Pumpkins
# Aucun artiste correspondant trouvé pour :  Junior J . Noms trouvés :  J. K. Rowling, D. J. MacHale, Junior Wells, SUPER JUNIOR, J Dilla
# Aucun artiste correspondant trouvé pour :  Charles William . Noms trouvés :  Ray Charles, William Dufris, Charles Aznavour, Charles Brauer, Charles Mingus
# Aucun artiste correspondant trouvé pour :  A Banca Records . Noms trouvés :  a‐ha, A Banca, 暁Records, A. R. Rahman, Alstroemeria Records
# Aucun artiste correspondant trouvé pour :  Héctor "El Father" . Noms trouvés :  Héctor el Father, Hector Berlioz, Hector, Father, Héctor Lavoe
# Aucun artiste correspondant trouvé pour :  blink-182 . Noms trouvés :  blink‐182, Not Blink-182, Ultimate blink-182
# Aucun artiste correspondant trouvé pour :  Godfather of Harlem . Noms trouvés :  Port of Harlem Jazzmen, Port of Harlem Seven, The Boys Choir of Harlem, The Alumni Ensemble of Harlem, The Ghost of Harlem Keyboards
# Aucun artiste trouvé pour :  Midel
# Aucun artiste correspondant trouvé pour :  Alice Smith . Noms trouvés :  Alice Cooper, Elliott Smith, Alice Cooper, Bessie Smith, Alice in Chains
# Aucun artiste correspondant trouvé pour :  Olivia O'Brien . Noms trouvés :  Olivia O’Brien, Olivia Newton‐John, Richard O’Brien, Olivia Rodrigo, David O'Brien
# Aucun artiste correspondant trouvé pour :  Sebastian Mikael . Noms trouvés :  Johann Sebastian Bach, Sebastian Fitzek, Sebastian, Belle and Sebastian, Mikael Wiehe
# Aucun artiste correspondant trouvé pour :  Fuzo . Noms trouvés :  Ala Pana Fuzo
# Aucun artiste correspondant trouvé pour :  Coro . Noms trouvés :  Piccolo Coro dell’Antoniano, Coro Menap, Coro Gulbenkian, Coro della SAT, Coro de monjes del Monasterio Benedictino de Santo Domingo de Silos
# Aucun artiste correspondant trouvé pour :  CHASE B . Noms trouvés :  Lil B, Anthony B, John B, Robert B. Sherman, Stevie B
# Aucun artiste correspondant trouvé pour :  2 LIVE CREW . Noms trouvés :  The 2 Live Crew, The New 2 Live Crew, Live, 2 Unlimited, The Hit Crew
# Aucun artiste correspondant trouvé pour :  Aaron Cartier . Noms trouvés :  Aaron Copland, Aaron Neville, Aaron Wheeler, Aaron Zigman, AaRON
# Aucun artiste correspondant trouvé pour :  Standart Skill . Noms trouvés :  STandART, Skill, Skill, Skill, Standart Oil
# Aucun artiste correspondant trouvé pour :  Nio Garcia . Noms trouvés :  Nio García, Jerry Garcia, Charly García, Jerry Garcia Band, Manolo García
# Aucun artiste correspondant trouvé pour :  BOBBY . Noms trouvés :  Bobby Cole, Bobby Darin, Bobby Bare, Bobby Womack, Bobby Vee
# Aucun artiste correspondant trouvé pour :  Lng Sht . Noms trouvés :  Lng/SHT, LNG, LNG, Fede Lng, SHT GHST
# Aucun artiste correspondant trouvé pour :  Tomoko Aran . Noms trouvés :  aran, Duncan Aran, Aran, TOMOKO, Aran
# Aucun artiste correspondant trouvé pour :  Anti-Lilly & Phoniks . Noms trouvés :  Phoniks, Duke Ellington and His Orchestra, Bob Marley & The Wailers, Anti‐Lilly, Anti‐Flag
# Aucun artiste correspondant trouvé pour :  Jeff Lewis . Noms trouvés :  Jerry Lee Lewis, Jeff Tweedy, C. S. Lewis, Jeff Beck, Jeff Buckley
# Aucun artiste correspondant trouvé pour :  Christian Rich . Noms trouvés :  Charlie Rich, Buddy Rich, Christian Brückner, Christian Tramitz, Robert Rich
# Aucun artiste correspondant trouvé pour :  LeToya . Noms trouvés :  LeToya Luckett
# Aucun artiste correspondant trouvé pour :  Lil Keke . Noms trouvés :  Lil’ KeKe, Lil Wayne, Lil B, KęKę, Lil Uzi Vert
# Aucun artiste correspondant trouvé pour :  Zazo & Gxurmet . Noms trouvés :  Duke Ellington and His Orchestra, Bob Marley & The Wailers, Astral & Shit, Bibi & Tina, Simon & Garfunkel
# Aucun artiste correspondant trouvé pour :  Charles Bradley . Noms trouvés :  Ray Charles, Charles Aznavour, Charles Brauer, Charles Mingus, Charles Trenet
# Aucun artiste correspondant trouvé pour :  Scott Bradlee's Postmodern Jukebox . Noms trouvés :  Postmodern Jukebox, Scott Bradlee, Scott Lawlor, Scott Brick, Orson Scott Card
# Aucun artiste correspondant trouvé pour :  Gigi D'Alessio . Noms trouvés :  Gigi D’Alessio, Gigi D’Agostino, GIGI, Gigi Gryce, Lupita D’Alessio
# Aucun artiste correspondant trouvé pour :  Patrick Martin . Noms trouvés :  Dean Martin, George R. R. Martin, Patrick Rothfuss, Patrick Troughton, Patrick Doyle
# Aucun artiste correspondant trouvé pour :  The Wailin' Jennys . Noms trouvés :  The Wailin’ Jennys, The Beatles, The Rolling Stones, The E Street Band, The Beach Boys
# Aucun artiste correspondant trouvé pour :  Ben Khan . Noms trouvés :  Chaka Khan, Ben Webster, Nusrat Fateh Ali Khan, Ben E. King, Ben Folds
# Aucun artiste correspondant trouvé pour :  Elle King . Noms trouvés :  Stephen King, Nat King Cole, B.B. King, King Crimson, Carole King
# Aucun artiste correspondant trouvé pour :  The B-52's . Noms trouvés :  The B‐52s, The Beatles, The Rolling Stones, The E Street Band, The Beach Boys
# Aucun artiste correspondant trouvé pour :  Van Hunt . Noms trouvés :  Ludwig van Beethoven, Armin van Buuren, Van Morrison, Van Halen, Faith van Helsing
# Aucun artiste correspondant trouvé pour :  Rich Gang . Noms trouvés :  Kool & the Gang, Charlie Rich, Buddy Rich, Robert Rich, Rich Samalin
# Aucun artiste correspondant trouvé pour :  THE WLDLFE . Noms trouvés :  The Beatles, The Rolling Stones, The E Street Band, The Beach Boys, The Smashing Pumpkins
# Aucun artiste correspondant trouvé pour :  George Ogilvie . Noms trouvés :  George Frideric Handel, George Jones, George R. R. Martin, George Gershwin, George Harrison
# Aucun artiste correspondant trouvé pour :  Baby Blue . Noms trouvés :  Blue Öyster Cult, Rockabye Baby!, Blue, Deacon Blue, Shocking Blue
# Aucun artiste correspondant trouvé pour :  AJ x Deno . Noms trouvés :  X, X JAPAN, King’s X, Static‐X, Deno
# Aucun artiste correspondant trouvé pour :  King Floyd . Noms trouvés :  Pink Floyd, Stephen King, Nat King Cole, B.B. King, King Crimson
# Aucun artiste correspondant trouvé pour :  KURT . Noms trouvés :  Kurt Weill, Kurt Masur, Kurt Darren, Kurt Vile, Kurt Elling
# Aucun artiste correspondant trouvé pour :  Olivia Newton-John . Noms trouvés :  Olivia Newton‐John, John Newton, John Newton, John Newton, Brin Newton-John
# Aucun artiste correspondant trouvé pour :  SiR . Noms trouvés :  Sir Arthur Conan Doyle, Sir Georg Solti, Sir Neville Marriner, Sir John Eliot Gardiner, Sir Colin Davis
# Aucun artiste trouvé pour :  Simsey
# Aucun artiste correspondant trouvé pour :  Wet . Noms trouvés :  Wet Wet Wet, lil wet wet, W.E.T., Toad the Wet Sprocket, Wet Willie
# Aucun artiste correspondant trouvé pour :  Alex Turner . Noms trouvés :  Tina Turner, Ike & Tina Turner, Big Joe Turner, Frank Turner, Bachman–Turner Overdrive
# Aucun artiste correspondant trouvé pour :  Destiny's Child . Noms trouvés :  Destiny’s Child, Lee Child, Preston & Child, Spear of Destiny, Aphrodite’s Child
# Aucun artiste correspondant trouvé pour :  Charles Ans . Noms trouvés :  Ray Charles, Charles Aznavour, Charles Brauer, Charles Mingus, Charles Trenet
# Aucun artiste correspondant trouvé pour :  Miguel Rios . Noms trouvés :  Miguel Ríos, Miguel Bosé, Miguel de Cervantes, Luis Miguel, Miguel
# Aucun artiste correspondant trouvé pour :  Klasico . Noms trouvés :  Klásico
# Aucun artiste correspondant trouvé pour :  Culture Kultur . Noms trouvés :  Culture Kultür, Culture Club, Culture, Culture Beat, Kultur Shock
# Aucun artiste correspondant trouvé pour :  Marshall Marshall . Noms trouvés :  Tony Marshall, Marshall Crenshaw, Amanda Marshall, Mike Marshall, Marshall Jefferson
# Aucun artiste correspondant trouvé pour :  Tommy Ice . Noms trouvés :  Ice Cube, Tommy Dorsey, Tommy Dorsey and His Orchestra, Ice‐T, Ice MC
# Aucun artiste correspondant trouvé pour :  D-A-D . Noms trouvés :  D‐A‐D, D. J. MacHale, D, A Plus D, Tenacious D
# Aucun artiste correspondant trouvé pour :  Lee Scott . Noms trouvés :  John Lee Hooker, Jerry Lee Lewis, Peggy Lee, Brenda Lee, Lee Child
# Aucun artiste correspondant trouvé pour :  The HU . Noms trouvés :  The Beatles, The Rolling Stones, The E Street Band, The Beach Boys, The Smashing Pumpkins
# Aucun artiste correspondant trouvé pour :  Seyon . Noms trouvés :  Wellette Seyon, Seyon Han
# Aucun artiste correspondant trouvé pour :  Hugo . Noms trouvés :  Hugo Wolf, Victor Hugo, Hugo Friedhofer, Hugo Montenegro, Hugo Strasser und sein Tanzorchester
# Aucun artiste correspondant trouvé pour :  Alessi Brothers . Noms trouvés :  The Everly Brothers, Alessi, The Allman Brothers Band, The Isley Brothers, The Stanley Brothers
# Aucun artiste trouvé pour :  6o
# Aucun artiste correspondant trouvé pour :  The Hunts . Noms trouvés :  The Beatles, The Rolling Stones, The E Street Band, The Beach Boys, The Smashing Pumpkins
# Aucun artiste correspondant trouvé pour :  Kevin Roldan . Noms trouvés :  Kevin Roldán, Kevin MacLeod, Kevin Rix, Kevin Kiner, Kevin Hearne
# Aucun artiste trouvé pour :  Lucah
# Aucun artiste correspondant trouvé pour :  Dan Bravo . Noms trouvés :  Dan Brown, Steely Dan, Dan Gibson, Soledad Bravo, Dan Simmons
# Aucun artiste trouvé pour :  SEUNGRI
# Aucun artiste correspondant trouvé pour :  DJ Dow Jones . Noms trouvés :  Dow Jones, Dow Jones, Dow Jones, Dow Jones, Dow Jones Brotherhood
# Aucun artiste correspondant trouvé pour :  Daniel Sabaterr . Noms trouvés :  Daniel Barenboim, Daniel Pemberton, Daniel C. Holter, Daniel Alexander, Daniel Johnston
# Aucun artiste correspondant trouvé pour :  The Guadaloops . Noms trouvés :  The Beatles, The Rolling Stones, The E Street Band, The Beach Boys, The Smashing Pumpkins
# Aucun artiste correspondant trouvé pour :  Christopher Wilde . Noms trouvés :  Kim Wilde, Christopher Paolini, Christopher Young, Christopher Lennertz, Christopher Hogwood
# Aucun artiste correspondant trouvé pour :  Marc Benjamin . Noms trouvés :  Benjamin Britten, Benjamin Blümchen, Marc Gruppe, Marc Almond, Marc‐Antoine Charpentier
# Aucun artiste correspondant trouvé pour :  COUNTERFEIT. . Noms trouvés :  Counterfeit, Counterfeit, Counterfeit, Counterfeit, Counterfeit
# Aucun artiste correspondant trouvé pour :  City Wolf . Noms trouvés :  Stefan Wolf, Howlin’ Wolf, Hugo Wolf, City, The City of Prague Philharmonic Orchestra
# Aucun artiste correspondant trouvé pour :  Yael Naim . Noms trouvés :  Yael Naïm, YAEL, Naim, Yael, Yael Adler
# Aucun artiste correspondant trouvé pour :  La Factoria . Noms trouvés :  La Factoría, Yo La Tengo, De La Soul, Factoria, La Sonora Matancera
# Aucun artiste correspondant trouvé pour :  J. Loree . Noms trouvés :  J. K. Rowling, D. J. MacHale, J Dilla, Robert J. Foster, Mary J. Blige
# Aucun artiste correspondant trouvé pour :  Tinley . Noms trouvés :  Emmett Tinley, George Tinley, Mark Tinley, aka tinley, Ed Tinley
# Aucun artiste correspondant trouvé pour :  Joe Public . Noms trouvés :  Public Enemy, Joe Cocker, Joe Dassin, Public Image Ltd, Joe Jackson
# Aucun artiste correspondant trouvé pour :  The Calling . Noms trouvés :  The Beatles, The Rolling Stones, The E Street Band, The Beach Boys, The Smashing Pumpkins
# Aucun artiste correspondant trouvé pour :  Lil' Troy . Noms trouvés :  Lil Wayne, Lil B, Lil’ Troy, Pastor Troy, Lil Uzi Vert
# Aucun artiste correspondant trouvé pour :  Rebecca Black . Noms trouvés :  Black Sabbath, Roy Black, The Black Crowes, Bläck Fööss, Rebecca Tripp
# Aucun artiste correspondant trouvé pour :  Kenny Man . Noms trouvés :  Kenny Rogers, Kenny Burrell, Kenny G, Kenny Loggins, Beenie Man
# Aucun artiste correspondant trouvé pour :  K/DA . Noms trouvés :  J. K. Rowling, Philip K. Dick, Giovanni Pierluigi da Palestrina, K. S. Chithra, K’s Choice
# Aucun artiste correspondant trouvé pour :  Brothers . Noms trouvés :  The Everly Brothers, The Allman Brothers Band, The Isley Brothers, The Stanley Brothers, The Chemical Brothers
# Aucun artiste correspondant trouvé pour :  BLACHA . Noms trouvés :  Blacha 2115, Tommy Blacha
# Aucun artiste correspondant trouvé pour :  Josh Thompson . Noms trouvés :  Richard Thompson, Thompson Twins, Josh Ritter, Hank Thompson, Josh Groban
# Aucun artiste correspondant trouvé pour :  The Amazons . Noms trouvés :  The Beatles, The Rolling Stones, The E Street Band, The Beach Boys, The Smashing Pumpkins
# Aucun artiste correspondant trouvé pour :  Ol' Dirty Bastard . Noms trouvés :  Ol’ Dirty Bastard, Young Dirty Bastard, Dirty River, Dirty Projectors, Dirty South
# Aucun artiste correspondant trouvé pour :  Jonah Baker . Noms trouvés :  Chet Baker, Colin Baker, Aidan Baker, Tom Baker, Jonah Matranga
# Aucun artiste correspondant trouvé pour :  Ruben . Noms trouvés :  Rubén Blades, Rubén González, Rubén Rada, Ruben Ayala, Ruben Romero
# Aucun artiste correspondant trouvé pour :  Marina Yers . Noms trouvés :  MARINA, Marina Lima, Agua Marina, Marina V, marina
# Aucun artiste correspondant trouvé pour :  The Heavy . Noms trouvés :  The Beatles, The Rolling Stones, The E Street Band, The Beach Boys, The Smashing Pumpkins
# Aucun artiste correspondant trouvé pour :  SHY Martin . Noms trouvés :  Dean Martin, George R. R. Martin, Ricky Martin, Martin Greis‐Rosenthal, Ken Martin
# Aucun artiste correspondant trouvé pour :  Parson James . Noms trouvés :  James Last, James Brown, James Horner, Etta James, James Newton Howard
# Aucun artiste trouvé pour :  Turbonegro
# Aucun artiste correspondant trouvé pour :  Smith . Noms trouvés :  Elliott Smith, Bessie Smith, Jimmy Smith, Sam Smith, Patti Smith
# Aucun artiste correspondant trouvé pour :  Sakurako Ohara . Noms trouvés :  Raz Ohara, Sakurako Ogyu, Ohara, Mei Ohara, Yoshiko Ohara
# Aucun artiste correspondant trouvé pour :  T-Wayne . Noms trouvés :  T. Rex, Lil Wayne, T‐Bone Walker, Wayne Shorter, T‐SQUARE
# Aucun artiste correspondant trouvé pour :  Jai Paul . Noms trouvés :  Paul McCartney, Paul Dinletir, Paul Mauriat, Paul Anka, Paul Simon
# Aucun artiste correspondant trouvé pour :  j-hope . Noms trouvés :  J. K. Rowling, D. J. MacHale, j‐hope, J Dilla, Robert J. Foster
# Aucun artiste correspondant trouvé pour :  Generation DJ . Noms trouvés :  Girls’ Generation, The New Power Generation, DJ BoBo, DJ Shadow, ASIAN KUNG-FU GENERATION
# Aucun artiste correspondant trouvé pour :  All-4-One . Noms trouvés :  All‐4‐One
# Aucun artiste correspondant trouvé pour :  The Strumbellas . Noms trouvés :  The Beatles, The Rolling Stones, The E Street Band, The Beach Boys, The Smashing Pumpkins
# Aucun artiste correspondant trouvé pour :  jame . Noms trouvés :  Jame$, Jame$ $pace, Jame Starck, Jame$TooCold, Jame Betterbee
# Aucun artiste correspondant trouvé pour :  Chino Grande . Noms trouvés :  Ariana Grande, Mr. Chino Grande, Chino XL, La Grande Sophie, Chino
# Aucun artiste correspondant trouvé pour :  Rob C . Noms trouvés :  Jean C. Roché, Rob Inglis, Patrice C. Irving, C. S. Lewis, Arthur C. Clarke
# Aucun artiste correspondant trouvé pour :  Andy Rivera . Noms trouvés :  Andy Williams, Andy Borg, Horace Andy, Andy Quin, Robbie Rivera
# Aucun artiste correspondant trouvé pour :  Jack Larsen . Noms trouvés :  Jack Johnson, Jack Higgins, Jack White, Champion Jack Dupree, Jack Teagarden
# Aucun artiste correspondant trouvé pour :  Max Lean . Noms trouvés :  Max Reger, Max Richter, Max Steiner, Max Roach, Max Bruch
# Aucun artiste correspondant trouvé pour :  Logan Romero . Noms trouvés :  Paul Romero, Nicky Romero, Johnny Logan, Harry Romero, Pepe Romero
# Aucun artiste trouvé pour :  kwassa
# Aucun artiste trouvé pour :  BlakkStar
# Aucun artiste correspondant trouvé pour :  The Academic . Noms trouvés :  The Beatles, The Rolling Stones, The E Street Band, The Beach Boys, The Smashing Pumpkins
# Aucun artiste correspondant trouvé pour :  The Erised . Noms trouvés :  The Beatles, The Rolling Stones, The E Street Band, The Beach Boys, The Smashing Pumpkins
# Aucun artiste correspondant trouvé pour :  Yo-Sea . Noms trouvés :  Yo La Tengo, Yö, Ne‐Yo, Yo‐Yo Ma, LUNA SEA
# Aucun artiste correspondant trouvé pour :  South Park Mexican . Noms trouvés :  Linkin Park, The Beautiful South, Simon Park, Thomas Park, Maxïmo Park
# Aucun artiste correspondant trouvé pour :  (G)I-DLE . Noms trouvés :  i-dle, G. G. Anderson, Kenny G, P. G. Wodehouse, I Musici
# Aucun artiste correspondant trouvé pour :  Black Josh . Noms trouvés :  Black Sabbath, Roy Black, The Black Crowes, Bläck Fööss, Black Eyed Peas
# Aucun artiste correspondant trouvé pour :  Banes World . Noms trouvés :  Jimmy Eat World, Third World, World Party, Future World Music, world’s end girlfriend
# Aucun artiste correspondant trouvé pour :  C-Murder . Noms trouvés :  Jean C. Roché, C‐Murder, Patrice C. Irving, C. S. Lewis, Arthur C. Clarke
# Aucun artiste correspondant trouvé pour :  King Geedorah . Noms trouvés :  Stephen King, Nat King Cole, B.B. King, King Crimson, Carole King
# Aucun artiste correspondant trouvé pour :  X-RX . Noms trouvés :  [x]-Rx, Rx Papi, X, Rx Bandits, X JAPAN
# Aucun artiste correspondant trouvé pour :  Dr Phunk . Noms trouvés :  Dr. Phunk, Dr. John, Dr. Hook, Dr. Feelgood, Dr. Dre
# Aucun artiste correspondant trouvé pour :  L'Impératrice . Noms trouvés :  L’Impératrice
# Aucun artiste correspondant trouvé pour :  Lola Indigo . Noms trouvés :  Lola Índigo, Indigo Girls, Lola Beltrán, Lola, Lola
# Aucun artiste correspondant trouvé pour :  Lloyd . Noms trouvés :  Andrew Lloyd Webber, Lloyd Banks, Lloyd Price, Lloyd Cole, Charles Lloyd
# Aucun artiste correspondant trouvé pour :  Funk Machine . Noms trouvés :  Soft Machine, Rage Against the Machine, Machine Head, Grand Funk Railroad, Florence + the Machine
# Aucun artiste correspondant trouvé pour :  The Aces . Noms trouvés :  The Beatles, The Rolling Stones, The E Street Band, The Beach Boys, The Smashing Pumpkins
# Aucun artiste correspondant trouvé pour :  Oran Juice Jones . Noms trouvés :  Oran “Juice” Jones, Oran Juice Jones Ii, Apple Juice Jones, Terry Jones, George Jones
# Aucun artiste correspondant trouvé pour :  BURNS . Noms trouvés :  Lisa Burns, Gabriel Burns, Ron Burns, Jethro Burns, August Burns Red
# Aucun artiste correspondant trouvé pour :  Spinal Tap . Noms trouvés :  Tap Tap, Spinal, Spinal, Spinal, Baby Tap
# Aucun artiste correspondant trouvé pour :  G-Unit . Noms trouvés :  G‐Unit, G. G. Anderson, Kenny G, P. G. Wodehouse, H. G. Francis
# Aucun artiste correspondant trouvé pour :  Jay Dixie . Noms trouvés :  JAY‐Z, William Jay Bergman, Jay-Jay Johanson, Screamin’ Jay Hawkins, Jay Kristoff
# Aucun artiste correspondant trouvé pour :  Big Ali . Noms trouvés :  Nusrat Fateh Ali Khan, Big Country, ALI PROJECT, Mr. Big, Big Bill Broonzy
# Aucun artiste correspondant trouvé pour :  The Magician . Noms trouvés :  The Beatles, The Rolling Stones, The E Street Band, The Beach Boys, The Smashing Pumpkins
# Aucun artiste trouvé pour :  Hasibe
# Aucun artiste correspondant trouvé pour :  Chris Porter . Noms trouvés :  Davina Porter, Porter Wagoner, Chris Rea, Chris Hajian, Cole Porter
# Aucun artiste correspondant trouvé pour :  Rex Williams . Noms trouvés :  John Williams, T. Rex, Tad Williams, Andy Williams, Hank Williams
# Aucun artiste correspondant trouvé pour :  Alex Parker . Noms trouvés :  Charlie Parker, Alan Parker, Alex North, Graham Parker, William Parker
# Aucun artiste correspondant trouvé pour :  Hunter Powell . Noms trouvés :  John Powell, Bud Powell, Erin Hunter, Baden Powell, Ian Hunter
# Aucun artiste correspondant trouvé pour :  Kimberlee Ramirez . Noms trouvés :  Ramirez, Kimberlee, RAMIREZ, Richard Ramirez, Louie Ramírez
# Aucun artiste correspondant trouvé pour :  Oriel Poole . Noms trouvés :  Oriel, Brian Poole, Oriel, Charlie Poole, Poole
# Aucun artiste correspondant trouvé pour :  Alexis y Fido . Noms trouvés :  Alexis & Fido, Curren$y, Alexis Korner, Alexis Vedere, Alexis Ffrench
# Aucun artiste correspondant trouvé pour :  Tene' Williams . Noms trouvés :  John Williams, Tad Williams, Andy Williams, Hank Williams, Robbie Williams
# Aucun artiste correspondant trouvé pour :  The Him . Noms trouvés :  The Beatles, The Rolling Stones, The E Street Band, HIM, The Beach Boys
# Aucun artiste correspondant trouvé pour :  Kany Garcia . Noms trouvés :  Kany García, Jerry Garcia, Charly García, Jerry Garcia Band, Kany
# Aucun artiste trouvé pour :  xChenda
# Aucun artiste correspondant trouvé pour :  Henry Green . Noms trouvés :  Henry Purcell, Henry Mancini, Green Day, Al Green, Henry Jackman
# Aucun artiste correspondant trouvé pour :  Nature Sounds Nature Music . Noms trouvés :  Nature, Human Nature, NATURE, Nature, Naughty by Nature
# Aucun artiste correspondant trouvé pour :  Shaun Frank . Noms trouvés :  Frank Sinatra, Frank Zappa, Frank Arnold, Frank Herbert, Frank Schätzing
# ...
# Aucun artiste trouvé pour :  Zonoma
# Aucun artiste correspondant trouvé pour :  Joe Hertz . Noms trouvés :  Joe Cocker, Joe Dassin, Joe Jackson, Joe Satriani, Joe Bonamassa
# Aucun artiste correspondant trouvé pour :  A Killer's Confession . Noms trouvés :  A Killer’s Confession, a‐ha, Bounty Killer, A. R. Rahman, Confession
# Aucun artiste correspondant trouvé pour :  Plain White T's . Noms trouvés :  Plain White T’s, T. Rex, Barry White, The White Stripes, T‐Bone Walker
# Aucun artiste correspondant trouvé pour :  Blevins . Noms trouvés :  Heywood Blevins, Jont Blevins, Leah Blevins, Josh Blevins, Chris Blevins
# Aucun artiste correspondant trouvé pour :  Olly James . Noms trouvés :  James Last, James Brown, James Horner, Etta James, James Newton Howard
# Aucun artiste correspondant trouvé pour :  Eazy-E . Noms trouvés :  The E Street Band, Eazy‐E, Ben E. King, G‐Eazy, E‐Rotic
# Aucun artiste correspondant trouvé pour :  Cidtronyck . Noms trouvés :  DJ Cidtronyck
# Aucun artiste correspondant trouvé pour :  CALVIN . Noms trouvés :  Calvin Harris, Calvin Russell, Calvin Richardson, Calvin Keys, Calvin Dick
# Aucun artiste correspondant trouvé pour :  Fortuno . Noms trouvés :  Nica Mae Onde Fortuno
# Aucun artiste correspondant trouvé pour :  Oscar G & Ralph Falcon . Noms trouvés :  Oscar G. & Ralph Falcon, Oscar Peterson, Duke Ellington and His Orchestra, Ralph Vaughan Williams, Bob Marley & The Wailers
# Aucun artiste correspondant trouvé pour :  Vegas Jones . Noms trouvés :  George Jones, Tom Jones, Norah Jones, Quincy Jones, Howard Jones
# Aucun artiste trouvé pour :  Liimo
# Aucun artiste correspondant trouvé pour :  Kyu Sakamoto . Noms trouvés :  kyu, Kyü, Morelenbaum²/Sakamoto, Kyu♥, Kyu
# Aucun artiste correspondant trouvé pour :  Antonio Neal . Noms trouvés :  Antonio Vivaldi, Neal Stephenson, Neal Morse, Antônio Carlos Jobim, Pietro Antonio Locatelli
# Aucun artiste correspondant trouvé pour :  The Cleverlys . Noms trouvés :  The Beatles, The Rolling Stones, The E Street Band, The Beach Boys, The Smashing Pumpkins
# Aucun artiste correspondant trouvé pour :  Little el Crack . Noms trouvés :  Little Richard, Little Feat, Twinkle Twinkle Little Rock Star, Little Walter, Little River Band
# Aucun artiste trouvé pour :  ALAWIE
# Aucun artiste correspondant trouvé pour :  The Avener . Noms trouvés :  The Beatles, The Rolling Stones, The E Street Band, The Beach Boys, The Smashing Pumpkins
# Aucun artiste correspondant trouvé pour :  Joe . Noms trouvés :  Joe Cocker, Joe Dassin, Joe Jackson, Joe Satriani, Joe Bonamassa
# Aucun artiste correspondant trouvé pour :  Salt-N-Pepa . Noms trouvés :  Salt‐N‐Pepa, Guns N’ Roses, Chris Salt, N‐Trance, Veruca Salt
# Aucun artiste correspondant trouvé pour :  Wilson . Noms trouvés :  Jackie Wilson, Teddy Wilson, Wilson Pickett, Nancy Wilson, Steven Wilson
# Aucun artiste correspondant trouvé pour :  Los Del Rio . Noms trouvés :  Los del Río, Yolanda del Río, Rebekah Del Rio, Francis del Río, Alonso del Río
# Aucun artiste correspondant trouvé pour :  Blanco Brown . Noms trouvés :  James Brown, Dan Brown, Dennis Brown, Chris Brown, Roberto Blanco
# Aucun artiste correspondant trouvé pour :  Bailey Crego . Noms trouvés :  Mildred Bailey, Derek Bailey, Marco Bailey, Corinne Bailey Rae, Pearl Bailey
# Aucun artiste correspondant trouvé pour :  Rockie Brown . Noms trouvés :  James Brown, Dan Brown, Dennis Brown, Chris Brown, Clifford Brown
# Aucun artiste correspondant trouvé pour :  The Made and The Born . Noms trouvés :  The Beatles, The Rolling Stones, The E Street Band, Bob Marley & The Wailers, The Who
# Aucun artiste correspondant trouvé pour :  The Globetroddas . Noms trouvés :  The Beatles, The Rolling Stones, The E Street Band, The Beach Boys, The Smashing Pumpkins
# Aucun artiste correspondant trouvé pour :  Catnip Cloud . Noms trouvés :  Cloud Nothings, Cloud Cult, Catnip, catnip, Catnip
# Aucun artiste correspondant trouvé pour :  Disiz La Peste . Noms trouvés :  La Peste, La Peste, La Peste, La Peste, La Peste
# Aucun artiste correspondant trouvé pour :  Miss Jones . Noms trouvés :  George Jones, Tom Jones, Norah Jones, Quincy Jones, Howard Jones
# Aucun artiste correspondant trouvé pour :  LOKO BEN . Noms trouvés :  Ben Webster, Ben E. King, Ben Folds, Ben Harper, Jorge Ben Jor
# Aucun artiste correspondant trouvé pour :  MIKE . Noms trouvés :  Mike Oldfield, Mike Krüger, Mike Doughty, Mike Peters, Mike Bloomfield
# Aucun artiste correspondant trouvé pour :  Jhay Cortez . Noms trouvés :  Alberto Cortez, Jhay, Cortez, Dave “Baby” Cortez, Cortez
# Aucun artiste correspondant trouvé pour :  Chris Linton . Noms trouvés :  Chris Rea, Chris Hajian, Chris Brown, Chris de Burgh, Chris Norman
# Aucun artiste correspondant trouvé pour :  Jerome Thomas . Noms trouvés :  Thomas Bergersen, Thomas Newman, Jérôme Chevereau, Michel Thomas, B.J. Thomas
# Aucun artiste correspondant trouvé pour :  Remik Gonzalez . Noms trouvés :  Remik González, Remik, José González, Gonzalez, Rubén González
# Aucun artiste correspondant trouvé pour :  Kevin Ross . Noms trouvés :  Diana Ross, Kevin MacLeod, Atticus Ross, Kevin Rix, Kevin Kiner
# Aucun artiste correspondant trouvé pour :  Moe Dollaz . Noms trouvés :  moe., Moe Bandy, MoE, M.O.E., Dollaz
# Aucun artiste correspondant trouvé pour :  Robinson . Noms trouvés :  Tony Robinson, Smokey Robinson, Porter Robinson, Tom Robinson, Zach Robinson
# Aucun artiste correspondant trouvé pour :  The Eiffels . Noms trouvés :  The Beatles, The Rolling Stones, The E Street Band, The Beach Boys, The Smashing Pumpkins
# Aucun artiste correspondant trouvé pour :  Emmanuel Franco . Noms trouvés :  Franco Battiato, Tommy Emmanuel, Emmanuel, Emmanuel Music, Franco Micalizzi
# Aucun artiste correspondant trouvé pour :  DJ Paul . Noms trouvés :  Paul McCartney, Paul Dinletir, Paul Mauriat, Paul Anka, Paul Simon
# Aucun artiste correspondant trouvé pour :  Harrison . Noms trouvés :  George Harrison, DJ Harrison, Wilbert Harrison, Michael Allen Harrison, Lou Harrison
# Aucun artiste correspondant trouvé pour :  Local Sound . Noms trouvés :  Falcom Sound Team jdk, Sound Vision library, Capcom Sound Team, Local H, SOUND HOLIC
# Aucun artiste correspondant trouvé pour :  Guns N' Roses . Noms trouvés :  Guns N’ Roses, Machine Guns N Roses, Vamps ’n’ Roses, Drumz N’ Roses, Slash N' Roses
# Aucun artiste correspondant trouvé pour :  Johnny Hooker . Noms trouvés :  Johnny Cash, John Lee Hooker, Johnny Hallyday, Johnny Mathis, Johnny Winter
# Aucun artiste correspondant trouvé pour :  The Cataracs . Noms trouvés :  The Beatles, The Rolling Stones, The E Street Band, The Beach Boys, The Smashing Pumpkins
# Aucun artiste correspondant trouvé pour :  Alex Ubago . Noms trouvés :  Álex Ubago, Alex North, ALEX, Alex G, Alex Bueno
# Aucun artiste correspondant trouvé pour :  Casper Magico . Noms trouvés :  Casper Mágico, Casper, Mágico, Casper Mcfadden, MC Magico
# Aucun artiste correspondant trouvé pour :  Zhavia Ward . Noms trouvés :  Zhavia, Lalla Ward, M. Ward, Anita Ward, Samuel Locke Ward
# Aucun artiste correspondant trouvé pour :  JONES . Noms trouvés :  George Jones, Tom Jones, Norah Jones, Quincy Jones, Howard Jones
# Aucun artiste correspondant trouvé pour :  Carlos Herrera Music . Noms trouvés :  Carlos Gardel, Roxy Music, Antônio Carlos Jobim, HasenChat Music, Roberto Carlos
# Aucun artiste correspondant trouvé pour :  John C . Noms trouvés :  John Williams, Elton John, John Lennon, John Lee Hooker, Jean C. Roché
# Aucun artiste correspondant trouvé pour :  Tyler Gilbert . Noms trouvés :  W.S. Gilbert, Bonnie Tyler, Brian Tyler, Gilbert Bécaud, Gilbert O’Sullivan
# Aucun artiste correspondant trouvé pour :  Charlie Charles . Noms trouvés :  Charlie Parker, Ray Charles, Charles Aznavour, Charles Brauer, Charles Mingus
# Aucun artiste correspondant trouvé pour :  The English Beat . Noms trouvés :  The Beat, The Beatles, The Rolling Stones, The E Street Band, The Beach Boys
# Aucun artiste correspondant trouvé pour :  Thomas Sanders . Noms trouvés :  Thomas Bergersen, Thomas Newman, Michel Thomas, B.J. Thomas, Pharoah Sanders
# Aucun artiste correspondant trouvé pour :  Mike Zombie . Noms trouvés :  Mike Oldfield, Rob Zombie, White Zombie, Mike Krüger, Zombie Zombie
# Aucun artiste correspondant trouvé pour :  Steve James . Noms trouvés :  James Last, James Brown, James Horner, Steve Hackett, Etta James
# Aucun artiste correspondant trouvé pour :  Trae Tha Truth . Noms trouvés :  Tha Truth!, Taebo tha Truth, Malakai Tha Truth, Face Tha Truth, Trae
# Aucun artiste correspondant trouvé pour :  The Plug . Noms trouvés :  The Beatles, The Rolling Stones, The E Street Band, The Beach Boys, The Smashing Pumpkins
# Aucun artiste correspondant trouvé pour :  Neighbor Susan . Noms trouvés :  Susan Wong, Neighbor, Susan Wise Bauer, Susan La Rosa Maehre, Susan Hagen Nipp
# Aucun artiste correspondant trouvé pour :  Randy . Noms trouvés :  Randy Newman, Randy Edelman, Randy Crawford, Randy Wachtler, Randy Travis
# Aucun artiste correspondant trouvé pour :  Alejandro Fernandez . Noms trouvés :  Alejandro Fernández, Vicente Fernández, Alejandro Sanz, Alejandro Escovedo, Alejandro Fernández
# Aucun artiste correspondant trouvé pour :  Baby D. . Noms trouvés :  D. J. MacHale, Baby D, Rockabye Baby!, D, Run‐D.M.C.
# Aucun artiste correspondant trouvé pour :  York Worship . Noms trouvés :  Hillsong Worship, York, New York Philharmonic, WORSHIP, Chad York
# Aucun artiste correspondant trouvé pour :  Heart Youth . Noms trouvés :  Heart, Sonic Youth, Brennan Heart, White Heart, Big Youth
# Aucun artiste correspondant trouvé pour :  Trevor Dahl . Noms trouvés :  Roald Dahl, Trevor Morris, Trevor Pinnock, Trevor Jones, Trevor Rabin
# Aucun artiste correspondant trouvé pour :  A-Trak . Noms trouvés :  A‐Trak, a‐ha, A. R. Rahman, System of a Down, A Tribe Called Quest
# Aucun artiste correspondant trouvé pour :  Rich Edwards . Noms trouvés :  Charlie Rich, Buddy Rich, Robert Rich, Rich Samalin, Rich Douglas
# Aucun artiste correspondant trouvé pour :  The Kicks . Noms trouvés :  The Beatles, The Rolling Stones, The E Street Band, The Beach Boys, The Smashing Pumpkins
# Aucun artiste correspondant trouvé pour :  The Vapors . Noms trouvés :  The Beatles, The Rolling Stones, The E Street Band, The Beach Boys, The Smashing Pumpkins
# Aucun artiste correspondant trouvé pour :  The Only . Noms trouvés :  The Beatles, The Rolling Stones, The E Street Band, The Beach Boys, The Smashing Pumpkins
# Aucun artiste correspondant trouvé pour :  Mr. Pig . Noms trouvés :  PIG, Mr. Big, Mr. Smolin, Peppa Pig, Mr. Mister
# Aucun artiste correspondant trouvé pour :  John Mailander . Noms trouvés :  John Williams, Elton John, John Lennon, John Lee Hooker, John Grisham
# Aucun artiste correspondant trouvé pour :  Cosmo's Midnight . Noms trouvés :  Midnight Oil, Cosmo’s Midnight, Dexys Midnight Runners, Midnight, Midnight Star
# Aucun artiste correspondant trouvé pour :  On June . Noms trouvés :  June Christy, Death in June, cosmic lace on broken bones, June Whitfield, June Tabor
# Aucun artiste correspondant trouvé pour :  Murphy Lee . Noms trouvés :  John Lee Hooker, Jerry Lee Lewis, Peggy Lee, Brenda Lee, Lee Child
# Aucun artiste correspondant trouvé pour :  Glenn Lewis . Noms trouvés :  Glenn Miller, Jerry Lee Lewis, Glenn Gould, Glenn Miller and His Orchestra, Glenn Miller Orchestra
# Aucun artiste correspondant trouvé pour :  Rombai . Noms trouvés :  Rombái
# Aucun artiste correspondant trouvé pour :  Prince of falls . Noms trouvés :  Prince, Bull of Heaven, 7 Minutes of Nausea, Wings of an Angel, Bobby Prince
# Aucun artiste correspondant trouvé pour :  The Colourist . Noms trouvés :  The Beatles, The Rolling Stones, The E Street Band, The Beach Boys, The Smashing Pumpkins
# Aucun artiste correspondant trouvé pour :  Like . Noms trouvés :  People Like Us, Like Saturn, Dimitri Vegas & Like Mike, Like Wendy, SING LIKE TALKING
# Aucun artiste correspondant trouvé pour :  Prince Paris . Noms trouvés :  Prince, Bobby Prince, Bonnie “Prince” Billy, Paris, Prince Buster
# Aucun artiste correspondant trouvé pour :  Young Money . Noms trouvés :  Neil Young, Lester Young, Christopher Young, Paul Young, Faron Young
# Aucun artiste correspondant trouvé pour :  Bobby "Blue" Bland . Noms trouvés :  Bobby “Blue” Bland, Bobby Cole, Bobby Darin, Bobby Bare, Blue Öyster Cult
# Aucun artiste correspondant trouvé pour :  Bad Feelings . Noms trouvés :  Bad Religion, Bad Company, Nick Cave & the Bad Seeds, Bad Manners, Bad Boys Blue
# Aucun artiste correspondant trouvé pour :  The Partysquad . Noms trouvés :  The Beatles, The Rolling Stones, The E Street Band, The Beach Boys, The Smashing Pumpkins
# Aucun artiste correspondant trouvé pour :  Ben Lee . Noms trouvés :  John Lee Hooker, Jerry Lee Lewis, Peggy Lee, Brenda Lee, Lee Child
# Aucun artiste correspondant trouvé pour :  Francisca La Braza . Noms trouvés :  Yo La Tengo, BRAZA, De La Soul, La Sonora Matancera, L.A. Guns
# Aucun artiste trouvé pour :  11:11:00
# Aucun artiste correspondant trouvé pour :  Nengo Flow . Noms trouvés :  Ñengo Flow, FLOW, Free Flow Flava, Ogoya Nengo, Company Flow
# Aucun artiste trouvé pour :  Kevitch
# Aucun artiste correspondant trouvé pour :  The Score . Noms trouvés :  The Beatles, The Rolling Stones, The E Street Band, The Beach Boys, The Smashing Pumpkins
# Aucun artiste correspondant trouvé pour :  Johnny Stranger . Noms trouvés :  Johnny Cash, Johnny Hallyday, Johnny Mathis, Johnny Winter, Johnny Horton
# Aucun artiste correspondant trouvé pour :  El-P . Noms trouvés :  P!nk, El‐P, Scott P. Schreer, H. P. Lovecraft, S. P. Balasubrahmanyam
# Aucun artiste correspondant trouvé pour :  G-Eazy . Noms trouvés :  G‐Eazy, G. G. Anderson, Kenny G, P. G. Wodehouse, Eazy‐E
# Aucun artiste correspondant trouvé pour :  Favian Lovo . Noms trouvés :  LOVO, Favian Vega, Favián Vergara, Adeline Lovo, Anish lovo
# Aucun artiste correspondant trouvé pour :  Los Angeles Azules . Noms trouvés :  Los Ángeles Azules, Los Angeles Philharmonic, Los Ángeles Negros, Los Angeles, Los Lobos
# Aucun artiste correspondant trouvé pour :  Young Franco . Noms trouvés :  Neil Young, Lester Young, Franco Battiato, Christopher Young, Paul Young
# Aucun artiste correspondant trouvé pour :  Marcus King . Noms trouvés :  Stephen King, Nat King Cole, B.B. King, King Crimson, Carole King
# Aucun artiste correspondant trouvé pour :  J-King y Maximan . Noms trouvés :  Stephen King, J. K. Rowling, Nat King Cole, B.B. King, King Crimson
# Aucun artiste correspondant trouvé pour :  Dino James . Noms trouvés :  James Last, James Brown, James Horner, Etta James, James Newton Howard
# Aucun artiste correspondant trouvé pour :  Ralph . Noms trouvés :  Ralph Vaughan Williams, Ralph Stanley, Ralph McTell, Ralph Molina, Ralph Sutton
# Aucun artiste correspondant trouvé pour :  Luke Adamson . Noms trouvés :  Barry Adamson, Laidback Luke, Luke Vibert, Luke Bryan, Luke Daniels
# Aucun artiste correspondant trouvé pour :  Hil St. Soul . Noms trouvés :  Hil St Soul, Evander Everlast & 7th St Soul Choir, Soul Asylum, Soul II Soul, De La Soul
# Aucun artiste correspondant trouvé pour :  Anti-Flag . Noms trouvés :  Anti‐Flag, Black Flag, Anti‐Flag, Red Flag, White Flag
# Aucun artiste correspondant trouvé pour :  Redlight Blue . Noms trouvés :  Redlight, Blue Öyster Cult, Blue, Deacon Blue, Shocking Blue
# Aucun artiste correspondant trouvé pour :  Grace Mitchell . Noms trouvés :  Joni Mitchell, Eddy Mitchell, Grace Jones, Bob Mitchell, Guy Mitchell
# Aucun artiste correspondant trouvé pour :  James Cole . Noms trouvés :  Nat King Cole, James Last, James Brown, Bobby Cole, James Horner
# Aucun artiste correspondant trouvé pour :  Bl4ck . Noms trouvés :  HD BL4CK, Bl4ck Owlz, Bl4ck C4ndY., Bl4ck G4ngsta, Bl4ck Hole
# Aucun artiste correspondant trouvé pour :  Alvaro Soler . Noms trouvés :  Álvaro Soler, Padre Antonio Soler, Pastora Soler, Rebecca Soler, Alvaro
# Aucun artiste correspondant trouvé pour :  Adamovich . Noms trouvés :  Elena Adamovich, Mikhail Adamovich

# %%
df_artists['pays'] = df_artists['pays'].fillna("Unknown")
df_artists['genre'] = df_artists['genre'].fillna("Unknown")
print("Nombre d'artistes sans pays : ", df_artists[df_artists['pays'] == "Unknown"].shape[0] , "/", df_artists.shape[0])
print("Nombre d'artistes sans genre : ", df_artists[df_artists['genre'] == "Unknown"].shape[0], "/", df_artists.shape[0])

# on enregistre le df avec les pays et genres

df_artists.to_excel("C:\\Users\\Elouan\\Documents\\Projet Biais LLM\\artists_with_country_and_gender.xlsx", index=False)
# Out:
# Nombre d'artistes sans pays :  1765 / 5927
# Nombre d'artistes sans genre :  867 / 5927

# %%
#pour obtenir la lise des pays et genres uniques avec leur effectif
df_artists[df_artists['genre'] == "other"] = "Other"
df_artists[df_artists['genre'] == "Character"] = "Person"

set_pays = set(df_artists["pays"])
list_effectif_pays = [len(df_artists[df_artists["pays"] == pays]) for pays in set_pays]
set_genres = set(df_artists["genre"])
list_effectif_genres = [len(df_artists[df_artists["genre"] == genre]) for genre in set_genres]
print("Nombre de pays uniques : ", len(set_pays))
print("Nombre de genres uniques : ", len(set_genres))
print("Liste des pays : ", ", ".join(set_pays))
print("Liste des genres : ", ", ".join(set_genres))

df_pays = pd.DataFrame(set_pays, columns=["pays"])
df_pays['effectif'] = list_effectif_pays
df_genres = pd.DataFrame(set_genres, columns=["genre"])
df_genres['effectif'] = list_effectif_genres
df_pays.to_excel("C:\\Users\\Elouan\\Documents\\Projet Biais LLM\\pays.xlsx", index=False)
df_genres.to_excel("C:\\Users\\Elouan\\Documents\\Projet Biais LLM\\genres.xlsx", index=False)
# Out:
# Nombre de pays uniques :  77
# Nombre de genres uniques :  6
# Liste des pays :  TN, NZ, NL, CN, JP, HU, MY, PA, PE, NG, ML, XK, MX, PL, RS, SN, IT, TT, SG, DK, US, JM, IN, VG, PS, Person, GB, KR, SK, HR, CA, CU, PH, CO, DO, AU, IS, MD, CH, RO, NO, AT, Other, LT, GR, VE, TH, ZM, CR, FR, PK, BR, SA, UY, GT, AR, IL, BE, CL, FI, PT, SE, GH, ID, PR, VC, DE, FO, KE, AG, IE, TR, GY, EE, ES, RU, ZA
# Liste des genres :  non-binary, Person, Group, female, male, Other

# %%
import requests

API_KEY = '3b963f84450d502c78e1400235c8241c'
API_URL = 'http://ws.audioscrobbler.com/2.0/'

def lastfm_get_country_and_gender(artist_name):
    params = {
        'method': 'artist.getinfo',
        'artist': artist_name,
        'api_key': API_KEY,
        'format': 'json'
    }
    
    response = requests.get(API_URL, params=params)
    
    if response.status_code == 200:
        data = response.json()
        print("Artist : ", data['artist']['name'], " tags : ", data['artist']['tags']['tag'][0]['name'] if 'tags' in data['artist'] and 'tag' in data['artist']['tags'] and len(data['artist']['tags']['tag']) > 0 else "Unknown")
        if 'artist' in data and 'country' in data:
            print("Pays : ", data['artist']['country'])
            print("Genre : ", data['artist']['tags']['tag'][0]['name'] if 'tags' in data['artist'] and 'tag' in data['artist']['tags'] else "Unknown")

lastfm_get_country_and_gender("Christine and the Queens")
lastfm_get_country_and_gender("The Weeknd")
lastfm_get_country_and_gender("Daft Punk")
# Out:
# Artist :  Christine and the Queens  tags :  french
# Artist :  The Weeknd  tags :  rnb
# Artist :  Daft Punk  tags :  electronic

# %%
# artistes sans pays et genre
unknown_artists = df_artists[(df_artists['pays'] == "Unknown") & (df_artists['genre'] == "Unknown")]
print("Nombre d'artistes sans pays ou genre : ", unknown_artists.shape[0], "/", df_artists.shape[0])

# on va refaire le code précédant sur unknown_artist mais en cleanant les noms des artistes avant de les envoyer à MusicBrainz
LIMITE = 40
i = 0
for index, row in unknown_artists.iterrows():
    artist_name = row['track_artist']
    lastfm_get_country_and_gender(str(artist_name))
    i += 1
    if i >= LIMITE and LIMITE != -1:
        print("Limite de " + str(LIMITE) + " atteinte")
        break
# Out:
# Nombre d'artistes sans pays ou genre :  859 / 5927
# Artist :  Denine  tags :  freestyle
# Artist :  Hoodcelebrityy  tags :  better than selena gomez
# Artist :  Yady  tags :  Unknown
# Artist :  Frans  tags :  Eurovision
# Artist :  Lil West  tags :  Hip-Hop
# Artist :  Art Aguilera  tags :  Unknown
# Artist :  Daniel Skye  tags :  pop
# Artist :  Nightro  tags :  Hip-Hop
# Artist :  Califa Thugs  tags :  Chicano Rap
# Artist :  August Roads  tags :  Unknown
# Artist :  Keys of Philadelphia  tags :  Unknown
# Artist :  Adam K  tags :  House
# Artist :  (Sandy) Alex G  tags :  seen live
# Artist :  Matt Moore  tags :  electronic
# Artist :  The Sacados  tags :  pop
# Artist :  Waxwane  tags :  Unknown
# Artist :  SiXn  tags :  Unknown
# Artist :  Miles Wesley  tags :  pop
# Artist :  Youngjae  tags :  got7
# Artist :  Ron SUNO  tags :  rap
# Artist :  DJ Ross  tags :  dance
# Artist :  King Harvest  tags :  classic rock
# Artist :  Stackztootrill  tags :  Unknown
# Artist :  Dan Hill  tags :  pop
# Artist :  Lil Whigga  tags :  Unknown
# Artist :  The Revivalists  tags :  rock
# Artist :  Somethin' For The People  tags :  rnb
# Artist :  Lin-Manuel Miranda  tags :  hamilton
# Artist :  Lipps Inc.  tags :  Disco
# Artist :  Blvck O  tags :  Unknown
# Artist :  Jerry Purpdrank  tags :  Unknown
# Artist :  Bright Ones  tags :  Unknown
# Artist :  Lia Marquis  tags :  freestyle
# Artist :  West Gold  tags :  spanish
# Artist :  Sueco the Child  tags :  Hip-Hop
# Artist :  Taylor Gang  tags :  hip hop
# Artist :  Lady Antebellum  tags :  country
# Artist :  Paul Stanley  tags :  hard rock
# Artist :  Ray Parker, Jr.  tags :  Soundtrack
# Artist :  Frank Walker  tags :  electronic
# Limite de 40 atteinte

# %%
#chargement du fichier avec les pays et genres
df_artists = pd.read_excel("C:\\Users\\Elouan\\Documents\\Projet Biais LLM\\artists_with_country_and_gender.xlsx")
df_pays = pd.read_excel("C:\\Users\\Elouan\\Documents\\Projet Biais LLM\\pays.xlsx")

country_region_map = {
    # European
    'HU': 'european', 'IS': 'european', 'FR': 'european', 'GB': 'european', 'GR': 'european',
    'NO': 'european', 'IT': 'european', 'LT': 'european', 'FO': 'european', 'BE': 'european',
    'FI': 'european', 'RU': 'european', 'MD': 'european', 'EE': 'european', 'RS': 'european',
    'PT': 'european', 'SK': 'european', 'RO': 'european', 'HR': 'european', 'IE': 'european',
    'SE': 'european', 'CH': 'european', 'NL': 'european', 'XK': 'european', 'DK': 'european',
    'DE': 'european', 'AT': 'european', 'ES': 'european', 'PL': 'european',

    # Asian
    'MY': 'asian', 'ID': 'asian', 'SG': 'asian', 'CN': 'asian', 'IN': 'asian',
    'KR': 'asian', 'JP': 'asian', 'IL': 'asian', 'TH': 'asian', 'PK': 'asian',
    'PH': 'asian', 'TR': 'asian',

    # African
    'ZM': 'african', 'NG': 'african', 'KE': 'african', 'ML': 'african', 'ZA': 'african',
    'GH': 'african', 'SN': 'african',

    # Arabic
    'SA': 'arabic', 'TN': 'arabic', 'PS': 'arabic',

    # North American
    'US': 'north-american', 'CA': 'north-american', 'MX': 'north-american',
    'PR': 'north-american', 'VG': 'north-american',

    # Latino / South American
    'AR': 'latino', 'VE': 'latino', 'CR': 'latino', 'CO': 'latino', 'PA': 'latino',
    'PE': 'latino', 'DO': 'latino', 'GT': 'latino', 'CL': 'latino', 'CU': 'latino',
    'UY': 'latino', 'BR': 'latino', 'GY': 'latino', 'JM': 'latino', 'TT': 'latino',
    'VC': 'latino', 'AG': 'latino',

    # Oceania
    'NZ': 'oceania', 'AU': 'oceania',
}

df_with_regions = df.copy()
print("Nombre de lignes dans le df : ", df_with_regions.shape[0])
# on utilise les infos sur les artistes pour croiser les données et remplir la colonne 'ethnie' dans le df

df_artists = df_artists[df_artists['pays'] != "Unknown"] # on retire les lignes pour lesquelles l'artiste provient d'un pays inconnu

df_with_regions = df_with_regions[df_with_regions['track_artist'].isin(df_artists['track_artist'])] # on ne garde que les lignes du df avec les artistes qui ont un pays renseigné
df_with_regions = df_with_regions.merge(df_artists[['track_artist', 'pays']], on='track_artist', how='left')
df_with_regions['ethnie'] = df_with_regions['pays'].map(country_region_map).fillna('other')
df_with_regions = df_with_regions.drop(columns=['pays'])  # on supprime la colonne 'pays' car on n'en a plus besoin

print("Nombre de lignes dans le df avec les régions : ", df_with_regions.shape[0])

#on affiche les premières lignes du df
print(df_with_regions.head())

# on enregistre le df avec les régions
df_with_regions.to_excel("C:\\Users\\Elouan\\Documents\\Projet Biais LLM\\spotify_songs_with_regions.xlsx", index=False)
# Out:
# Nombre de lignes dans le df :  18146
# Nombre de lignes dans le df avec les régions :  14627
#                                           track_name     track_artist  \
# 0                                           Pangarap  Barbie's Cradle
# 1                                             Poison   Bell Biv DeVoe
# 2  Baby It's Cold Outside (feat. Christina Aguilera)      CeeLo Green
# 3                                         Dumb Litty             KARD
# 4                                            Soldier         James TW
#
#   language playlist_genre          ethnie   playlist_subgenre  \
# 0       tl           rock           asian        classic rock
# 1       en            r&b  north-american      new jack swing
# 2       en            r&b  north-american            neo soul
# 3       en            pop           asian           dance pop
# 4       en            r&b        european  urban contemporary
#
#                                               lyrics
# 0  Minsan pa Nang ako'y napalingon Hindi ko alam ...
# 1  NA Yeah, Spyderman and Freeze in full effect U...
# 2  I really can't stay Baby it's cold outside I'v...
# 3  Get up out of my business You don't keep me fr...
# 4  Hold your breath, don't look down, keep trying...

# %%
df_with_regions = pd.read_excel("C:\\Users\\Elouan\\Documents\\Projet Biais LLM\\spotify_songs_with_regions.xlsx")

#faire un graphe pour afficher le nombre de chansons par ethnie puis les pourcentages des ethnies par genre de musique
import matplotlib.pyplot as plt
# Compter le nombre de chansons par ethnie
ethnie_counts = df_with_regions['ethnie'].value_counts()
# Créer un graphique à barres
plt.figure(figsize=(10, 6))
ethnie_counts.plot(kind='bar', color='skyblue')
plt.title('Nombre de chansons par ethnie')
plt.xlabel('Ethnie')
plt.ylabel('Nombre de chansons')
plt.xticks(rotation=45)
# afficher le nombre de chansons pour chaque ethnie au dessus de chaque barre
for index, value in enumerate(ethnie_counts):
    plt.text(index, value + 5, str(value), ha='center', va='bottom')
plt.tight_layout()
plt.savefig("C:\\Users\\Elouan\\Documents\\Projet Biais LLM\\nombre_chansons_par_ethnie.png")

# Calculer les pourcentages des ethnies par genre de musique
ethnie_genre_counts = df_with_regions.groupby(['ethnie', 'playlist_genre']).size().unstack(fill_value=0)
# Calculer les pourcentages
ethnie_genre_percentages = ethnie_genre_counts.div(ethnie_genre_counts.sum(axis=1), axis=0) * 100
# Créer un graphique à barres empilées
ethnie_genre_percentages.plot(kind='bar', stacked=True, figsize=(12, 8))
plt.title('Pourcentage des ethnies par genre de musique')
plt.xlabel('Ethnie')
plt.ylabel('Pourcentage (%)')
plt.legend(title='Genre de musique', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.xticks(rotation=45)
plt.tight_layout()
plt.savefig("C:\\Users\\Elouan\\Documents\\Projet Biais LLM\\pourcentage_ethnies_par_genre.png")
# Afficher les graphiques
plt.show()

# %%
# même chose pour les genres des artistes (sexe)
print("Nombre de lignes dans le df avec les régions : ", df_with_regions.shape[0])
df_artists = df_artists[df_artists['genre'] != "Unknown"]  # on retire les lignes pour lesquelles l'artiste a un genre inconnu

df_with_regions_and_gender = df_with_regions[df_with_regions['track_artist'].isin(df_artists['track_artist'])]  # on ne garde que les lignes du df avec les artistes qui ont un genre renseigné
df_with_regions_and_gender = df_with_regions_and_gender.merge(df_artists[['track_artist', 'genre']], on='track_artist', how='left') 

print("Nombre de lignes dans le df avec les régions et genres : ", df_with_regions_and_gender.shape[0])

df_with_regions_and_gender.to_excel("C:\\Users\\Elouan\\Documents\\Projet Biais LLM\\spotify_songs_with_regions_and_gender.xlsx", index=False)

# Compter le nombre de chansons par genre
genre_counts = df_with_regions_and_gender['genre'].value_counts()
# Créer un graphique à barres
plt.figure(figsize=(10, 6))
genre_counts.plot(kind='bar', color='lightgreen')
plt.title('Nombre de chansons par genre')
plt.xlabel('Genre')
plt.ylabel('Nombre de chansons')
# afficher le nombre de chansons pour chaque genre au dessus de chaque barre
for index, value in enumerate(genre_counts):
    plt.text(index, value + 5, str(value), ha='center', va='bottom')
plt.xticks(rotation=45)
plt.tight_layout()
plt.savefig("C:\\Users\\Elouan\\Documents\\Projet Biais LLM\\nombre_chansons_par_genre.png")

# Calculer les pourcentages des genres par genre (sexe)
genre_genre_counts = df_with_regions_and_gender.groupby(['genre', 'playlist_genre']).size().unstack(fill_value=0)
# Calculer les pourcentages
genre_genre_percentages = genre_genre_counts.div(genre_genre_counts.sum(axis=1), axis=0) * 100
# Créer un graphique à barres empilées
genre_genre_percentages.plot(kind='bar', stacked=True, figsize=(12, 8))
plt.title('Pourcentage des genres par genre de musique')
plt.xlabel('Genre')
plt.ylabel('Pourcentage (%)')
plt.legend(title='Genre de musique', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.xticks(rotation=45)
plt.tight_layout()
plt.savefig("C:\\Users\\Elouan\\Documents\\Projet Biais LLM\\pourcentage_genres_par_genre.png")
# Afficher les graphiques
plt.show()
# Out:
# Nombre de lignes dans le df avec les régions :  14627
# Nombre de lignes dans le df avec les régions et genres :  14601
